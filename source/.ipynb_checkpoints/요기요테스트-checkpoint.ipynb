# %%
from IPython.display import display, HTML 
display(HTML("""
<style>
div.container{width:86% !important;}
div.cell.code_cell.rendered{width:100%;}
div.CodeMirror {font-family:Consolas; font-size:15pt;}
div.output {font-size:15pt; font-weight:bold;}
div.input {font-family:Consolas; font-size:15pt;}
div.prompt {min-width:70px;}
div#toc-wrapper{padding-top:120px;}
div.text_cell_render ul li{font-size:12pt;padding:5px;}
table.dataframe{font-size:15px;}
</style>
"""))
# Out:
# <style>
# div.container{width:86% !important;}
# div.cell.code_cell.rendered{width:100%;}
# div.CodeMirror {font-family:Consolas; font-size:15pt;}
# div.output {font-size:15pt; font-weight:bold;}
# div.input {font-family:Consolas; font-size:15pt;}
# div.prompt {min-width:70px;}
# div#toc-wrapper{padding-top:120px;}
# div.text_cell_render ul li{font-size:12pt;padding:5px;}
# table.dataframe{font-size:15px;}
# </style>

# %%
import re
import time
from bs4 import BeautifulSoup
from selenium import webdriver
from selenium.webdriver.chrome.service import Service
from selenium.webdriver.common.by import By
from selenium.webdriver.common.keys import Keys

# 크롬 드라이버 경로 설정
driver = webdriver.Chrome()
driver.maximize_window()
driver.get('https://www.yogiyo.co.kr/')
time.sleep(0.1)  # 페이지 로딩 대기 (필요 시 더 길게 조정)

elem = driver.find_element(By.CLASS_NAME, 'btn.btn-default.ico-loc')
elem.click()
print(elem)
driver.implicitly_wait(10)
# Out:
# <selenium.webdriver.remote.webelement.WebElement (session="5818f3046a4fc5619633966ae29b7d47", element="f.48918E436D2C65418233F60B2CC444F0.d.389A89D2C6714041A6DDF91D860CCDAE.e.67")>

# %%
# 따로 땔 줄 몰라서 일단 분리 실행
# elem = driver.find_elements(By.CLASS_NAME, 'category-name')
# print(len(elem))
# print(elem[1])

# time.sleep(0.1)
from selenium.webdriver.support.ui import Select


category_items = driver.find_elements(By.CLASS_NAME, "category-name")
for item in category_items:
    if "치킨" in item.text:
        print("클릭 대상:", item.text)
        item.click()
        break
driver.implicitly_wait(10)

select_element = driver.find_element(By.CSS_SELECTOR, "select.form-control")

# Selenium의 Select 객체로 감싸기
select = Select(select_element)

# '리뷰 많은순'을 선택 (value 또는 visible text로 가능)
select.select_by_value("review_count")

# for item in category_items:
#     print(item.text)
time.sleep(0.4)
driver.implicitly_wait(10)

elem = driver.find_elements(By.CLASS_NAME, 'item.clearfix')
print(len(elem))
test = []
for a in elem:
    test.append(a.text.split('\n')[0])
# Out:
# 클릭 대상: 치킨
# 60

# %%
print(len(test))
print(len(set(test)))
from itertools import zip_longest  

for a, b in zip_longest(test, set(test)) :
    if(a.text.split('\n')[0] != b.text.split('\n')[0]):
        print(a.text.split('\n')[0])
# Out:
# 60
# 56
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[141], line 6
#       3 from itertools import zip_longest
#       5 for a, b in zip_longest(test, set(test)) :
# ----> 6     if(a.text.split('\n')[0] != b.text.split('\n')[0]):
#       7         print(a.text.split('\n')[0])
#
# AttributeError: 'str' object has no attribute 'text'

# %%
# 렌더링된 페이지 소스 가져오기
soup = BeautifulSoup(driver.page_source, 'html.parser')

# 이미지 div 추출
photo_divs = soup.find_all('div', class_='photo')
menu = soup.find_all('div', class_='menu-name')

for div_p, div_m in zip(photo_divs, menu):
    style = div_p.get('style', '')
    image_urls = re.findall(r"url\('([^']+)'\)", style)
    print(image_urls[0])
#     print(div_m.text)
#     for idx, image_url in enumerate(image_urls):
#         print(f"이미지 URL: {image_url}")
# driver.quit()

# %%
print(len(set(photo_divs)))
len(set(menu))
# Out:
# 74
# 77

# %%
# for a in set(menu) :
#     print(a.text)
    
for i, div_p in enumerate(set(photo_divs)) :
    style = div_p.get('style', '')
    image_urls = re.findall(r"url\('([^']+)'\)", style)
    print(image_urls[0])
    if(extract_menu_name(image_urls[0]) == "메뉴명 추출 실패"):
        print(i)
        print(image_urls[0])
# Out:
# https://images.yogiyo.co.kr/image/yogiyo/PARTNER_FR_IMG/%EC%B2%AD%EB%85%84%ED%94%BC%EC%9E%90/2024-07-09/%EC%A0%9C%ED%9C%B4FR_20240709_%EC%B2%AD%EB%85%84%ED%94%BC%EC%9E%90_%ED%8C%8C%EC%9D%B8%EC%95%A0%ED%94%8C%EC%B6%94%EA%B0%80_1080x640.jpg?width=384&height=273&quality=100
# https://images.yogiyo.co.kr/image/yogiyo/PARTNER_FR_IMG/%EC%B2%AD%EB%85%84%ED%94%BC%EC%9E%90/2024-07-09/%EC%A0%9C%ED%9C%B4FR_20240709_%EC%B2%AD%EB%85%84%ED%94%BC%EC%9E%90_%ED%8E%98%ED%8E%98%EB%A1%9C%EB%8B%88%EC%B6%94%EA%B0%80-20%EA%B0%9C_1080x640.jpg?width=384&height=273&quality=100
# https://images.yogiyo.co.kr/image/yogiyo/PARTNER_FR_IMG/%EC%B2%AD%EB%85%84%ED%94%BC%EC%9E%90/2024-07-09/%EC%A0%9C%ED%9C%B4FR_20240709_%EC%B2%AD%EB%85%84%ED%94%BC%EC%9E%90_%EA%B0%88%EB%A6%AD%EB%8F%84%EA%B7%B8%EC%8A%A4%ED%8B%B1_1080x640.jpg?width=384&height=273&quality=100
# https://images.yogiyo.co.kr/image/yogiyo/PARTNER_FR_IMG/%EC%B2%AD%EB%85%84%ED%94%BC%EC%9E%90/2024-07-09/%EC%A0%9C%ED%9C%B4FR_20240709_%EC%B2%AD%EB%85%84%ED%94%BC%EC%9E%90_%EC%94%A8%ED%91%B8%EB%93%9C%EC%BD%98%EB%B0%94%EC%8A%A4%EC%BC%93_1080x640.jpg?width=384&height=273&quality=100
# https://images.yogiyo.co.kr/image/yogiyo/PARTNER_FR_IMG/%EC%B2%AD%EB%85%84%ED%94%BC%EC%9E%90/2025-02-28/%EC%A0%9C%ED%9C%B4FR_20250227_%EC%B2%AD%EB%85%84%ED%94%BC%EC%9E%90_%EB%B0%98%EB%B0%98-%ED%94%84%EB%A6%AC%EB%AF%B8%EC%97%84R_1080x640.jpg?width=384&height=273&quality=100
# https://images.yogiyo.co.kr/image/yogiyo/PARTNER_FR_IMG/%EC%B2%AD%EB%85%84%ED%94%BC%EC%9E%90/2024-12-13/%EC%A0%9C%ED%9C%B4FR_20241212_%EC%B2%AD%EB%85%84%ED%94%BC%EC%9E%90_%EC%98%A4%EB%A6%AC%EC%A7%80%EB%84%90-%EC%8B%A0%EB%A9%94%EB%89%B4-%EA%B7%B8%EB%A6%B4%EB%93%9C-%EC%99%80%EC%9D%BC%EB%93%9C-%ED%86%B5%EB%8B%A4%EB%A6%AC_1080x640.jpg?width=384&height=273&quality=100
# https://images.yogiyo.co.kr/image/yogiyo/PARTNER_FR_IMG/%EC%B2%AD%EB%85%84%ED%94%BC%EC%9E%90/2024-12-13/%EC%A0%9C%ED%9C%B4FR_20241212_%EC%B2%AD%EB%85%84%ED%94%BC%EC%9E%90_%EC%8B%A0%EB%A9%94%EB%89%B4-%ED%81%AC%EB%A6%AC%EC%8A%A4%ED%94%BC-%ED%95%AB%EC%9C%99-4%EA%B0%9C_1080x640.jpg?width=384&height=273&quality=100
# https://images.yogiyo.co.kr/image/yogiyo/PARTNER_FR_IMG/%EC%B2%AD%EB%85%84%ED%94%BC%EC%9E%90/2024-07-09/%EC%A0%9C%ED%9C%B4FR_20240709_%EC%B2%AD%EB%85%84%ED%94%BC%EC%9E%90_%EC%95%8C%EB%A6%AC%EC%98%A4%EC%98%AC%EB%A6%AC%EC%98%A4%ED%8C%8C%EC%8A%A4%ED%83%80_1080x640.jpg?width=384&height=273&quality=100
# https://images.yogiyo.co.kr/image/yogiyo/PARTNER_FR_IMG/%EC%B2%AD%EB%85%84%ED%94%BC%EC%9E%90/2024-07-09/%EC%A0%9C%ED%9C%B4FR_20240709_%EC%B2%AD%EB%85%84%ED%94%BC%EC%9E%90_%EB%A1%9C%EC%A0%9C%EC%89%AC%EB%A6%BC%ED%94%84%ED%8C%8C%EC%8A%A4%ED%83%80_1080x640.jpg?width=384&height=273&quality=100
# https://images.yogiyo.co.kr/image/yogiyo/PARTNER_FR_IMG/%EC%B2%AD%EB%85%84%ED%94%BC%EC%9E%90/2024-07-09/%EC%A0%9C%ED%9C%B4FR_20240709_%EC%B2%AD%EB%85%84%ED%94%BC%EC%9E%90_%ED%95%A0%EB%9D%BC%ED%94%BC%EB%87%A8_1080x640.jpg?width=384&height=273&quality=100
# https://images.yogiyo.co.kr/image/yogiyo/PARTNER_FR_IMG/%EC%B2%AD%EB%85%84%ED%94%BC%EC%9E%90/2024-07-09/%EC%A0%9C%ED%9C%B4FR_20240709_%EC%B2%AD%EB%85%84%ED%94%BC%EC%9E%90_%EC%98%A5%EC%88%98%EC%88%98%EC%B6%94%EA%B0%80_1080x640.jpg?width=384&height=273&quality=100
# https://images.yogiyo.co.kr/image/yogiyo/PARTNER_FR_IMG/%EC%B2%AD%EB%85%84%ED%94%BC%EC%9E%90/2024-07-09/%EC%A0%9C%ED%9C%B4FR_20240709_%EC%B2%AD%EB%85%84%ED%94%BC%EC%9E%90_%ED%95%A0%EB%9D%BC%ED%94%BC%EB%87%A8_%ED%86%A0%ED%95%91%EC%B6%94%EA%B0%80_1080x640.jpg?width=384&height=273&quality=100
# https://images.yogiyo.co.kr/image/yogiyo/PARTNER_FR_IMG/%EC%B2%AD%EB%85%84%ED%94%BC%EC%9E%90/2024-07-09/%EC%A0%9C%ED%9C%B4FR_20240709_%EC%B2%AD%EB%85%84%ED%94%BC%EC%9E%90_%EB%A7%A4%EB%93%9C%EC%89%AC%EB%A6%BC%ED%94%84_1080x640.jpg?width=384&height=273&quality=100
# https://images.yogiyo.co.kr/image/yogiyo/PARTNER_FR_IMG/%EC%B2%AD%EB%85%84%ED%94%BC%EC%9E%90/2024-07-09/%EC%A0%9C%ED%9C%B4FR_20240709_%EC%B2%AD%EB%85%84%ED%94%BC%EC%9E%90_%EB%A6%AC%EC%96%BC%ED%8E%98%ED%8E%98%EB%A1%9C%EB%8B%88_1080x640.jpg?width=384&height=273&quality=100
# https://images.yogiyo.co.kr/image/yogiyo/PARTNER_FR_IMG/%EC%B2%AD%EB%85%84%ED%94%BC%EC%9E%90/2024-12-13/%EC%A0%9C%ED%9C%B4FR_20241212_%EC%B2%AD%EB%85%84%ED%94%BC%EC%9E%90_%ED%94%84%EB%A6%AC%EB%AF%B8%EC%97%84-%EC%8B%A0%EB%A9%94%EB%89%B4-%EA%B7%B8%EB%A6%B4%EB%93%9C-%EC%99%80%EC%9D%BC%EB%93%9C-%ED%86%B5%EB%8B%A4%EB%A6%AC_1080x640.jpg?width=384&height=273&quality=100
# https://images.yogiyo.co.kr/image/yogiyo/PARTNER_FR_IMG/%EC%B2%AD%EB%85%84%ED%94%BC%EC%9E%90/2024-07-09/%EC%A0%9C%ED%9C%B4FR_20240709_%EC%B2%AD%EB%85%84%ED%94%BC%EC%9E%90_%EA%B3%A0%EA%B5%AC%EB%A7%88%ED%81%AC%EB%A6%BC%EC%B9%98%EC%A6%88%EC%8A%A4%ED%8B%B1_1080x640.jpg?width=384&height=273&quality=100
# https://images.yogiyo.co.kr/image/yogiyo/PARTNER_FR_IMG/%EC%B2%AD%EB%85%84%ED%94%BC%EC%9E%90/2024-07-09/%EC%A0%9C%ED%9C%B4FR_20240709_%EC%B2%AD%EB%85%84%ED%94%BC%EC%9E%90_%EB%B6%88%EA%B3%A0%EA%B8%B0%ED%81%AC%EB%A6%BC%ED%8C%8C%EC%8A%A4%ED%83%80_1080x640.jpg?width=384&height=273&quality=100
# https://images.yogiyo.co.kr/image/yogiyo/PARTNER_FR_IMG/%EC%B2%AD%EB%85%84%ED%94%BC%EC%9E%90/2024-07-09/%EC%A0%9C%ED%9C%B4FR_20240709_%EC%B2%AD%EB%85%84%ED%94%BC%EC%9E%90_%EC%98%AC%EB%A6%AC%EB%B8%8C%EC%B6%94%EA%B0%80_1080x640.jpg?width=384&height=273&quality=100
# https://images.yogiyo.co.kr/image/yogiyo/PARTNER_FR_IMG/%EC%B2%AD%EB%85%84%ED%94%BC%EC%9E%90/2024-07-09/%EC%A0%9C%ED%9C%B4FR_20240709_%EC%B2%AD%EB%85%84%ED%94%BC%EC%9E%90_%EC%98%A4%EB%A6%AC%EC%A7%80%EB%84%90Ln%ED%94%84%EB%A6%AC%EB%AF%B8%EC%97%84L_1080x640.jpg?width=384&height=273&quality=100
# https://images.yogiyo.co.kr/image/yogiyo/PARTNER_FR_IMG/%EC%B2%AD%EB%85%84%ED%94%BC%EC%9E%90/2024-12-13/%EC%A0%9C%ED%9C%B4FR_20241212_%EC%B2%AD%EB%85%84%ED%94%BC%EC%9E%90_%EC%8B%A0%EB%A9%94%EB%89%B4-%EC%B9%98%EC%A6%88%EC%88%98%ED%94%8C%EB%A0%88-%EB%AF%B8%ED%8A%B8%ED%8C%8C%EC%9D%B4-%ED%94%BC%EC%9E%90_1080x640.jpg?width=384&height=273&quality=100
# https://images.yogiyo.co.kr/image/yogiyo/PARTNER_FR_IMG/%EC%B2%AD%EB%85%84%ED%94%BC%EC%9E%90/2024-07-09/%EC%A0%9C%ED%9C%B4FR_20240709_%EC%B2%AD%EB%85%84%ED%94%BC%EC%9E%90_%EC%98%A4%EB%A6%AC%EC%A7%80%EB%84%90Rn%EC%B2%AD%ED%94%BC%EC%8A%A4%ED%8B%B1%EC%84%B8%ED%8A%B8_1080x640.jpg?width=384&height=273&quality=100
# https://images.yogiyo.co.kr/image/yogiyo/PARTNER_FR_IMG/%EC%B2%AD%EB%85%84%ED%94%BC%EC%9E%90/2024-07-09/%EC%A0%9C%ED%9C%B4FR_20240709_%EC%B2%AD%EB%85%84%ED%94%BC%EC%9E%90_%EA%B5%AD%EB%82%B4%EC%82%B0_%EC%98%A4%EB%B8%90%EB%B2%A0%EC%9D%B4%ED%81%AC%EC%B9%98%ED%82%A8_1080x640.jpg?width=384&height=273&quality=100
# https://images.yogiyo.co.kr/image/yogiyo/PARTNER_FR_IMG/%EC%B2%AD%EB%85%84%ED%94%BC%EC%9E%90/2024-07-09/%EC%A0%9C%ED%9C%B4FR_20240709_%EC%B2%AD%EB%85%84%ED%94%BC%EC%9E%90_%EB%A7%88%EC%9A%94%EB%84%A4%EC%A6%88%EC%B6%94%EA%B0%80_1080x640.jpg?width=384&height=273&quality=100
# https://images.yogiyo.co.kr/image/yogiyo/PARTNER_FR_IMG/%EC%B2%AD%EB%85%84%ED%94%BC%EC%9E%90/2024-07-09/%EC%A0%9C%ED%9C%B4FR_20240709_%EC%B2%AD%EB%85%84%ED%94%BC%EC%9E%90_%EB%B0%98%EB%B0%98%ED%94%84%EB%A6%AC%EB%AF%B8%EC%97%84L_1080x640.jpg?width=384&height=273&quality=100
# https://images.yogiyo.co.kr/image/yogiyo/PARTNER_FR_IMG/%EC%B2%AD%EB%85%84%ED%94%BC%EC%9E%90/2024-07-09/%EC%A0%9C%ED%9C%B4FR_20240709_%EC%B2%AD%EB%85%84%ED%94%BC%EC%9E%90_%EC%BD%94%EC%B9%B4%EC%BD%9C%EB%9D%BC1250mL_1080x640.jpg?width=384&height=273&quality=100
# https://images.yogiyo.co.kr/image/yogiyo/PARTNER_FR_IMG/%EC%B2%AD%EB%85%84%ED%94%BC%EC%9E%90/2024-12-13/%EC%A0%9C%ED%9C%B4FR_20241212_%EC%B2%AD%EB%85%84%ED%94%BC%EC%9E%90_%EB%B9%85%ED%8C%8C-%EB%B6%88%EA%B3%A0%EA%B8%B0-%ED%94%BC%EC%9E%90_1080x640.jpg?width=384&height=273&quality=100
# https://images.yogiyo.co.kr/image/yogiyo/PARTNER_FR_IMG/%EC%B2%AD%EB%85%84%ED%94%BC%EC%9E%90/2024-07-09/%EC%A0%9C%ED%9C%B4FR_20240709_%EC%B2%AD%EB%85%84%ED%94%BC%EC%9E%90_%ED%95%AB%EC%9C%99%EB%B4%895%EA%B0%9C_1080x640.jpg?width=384&height=273&quality=100
# https://images.yogiyo.co.kr/image/yogiyo/PARTNER_FR_IMG/%EC%B2%AD%EB%85%84%ED%94%BC%EC%9E%90/2024-07-09/%EC%A0%9C%ED%9C%B4FR_20240709_%EC%B2%AD%EB%85%84%ED%94%BC%EC%9E%90_%EA%B5%AD%EB%82%B4%EC%82%B0_%ED%9B%84%EB%9D%BC%EC%9D%B4%EB%93%9C%EC%B9%98%ED%82%A8%EB%8B%AD%EB%8B%A4%EB%A6%AC2%EA%B0%9C_1080x640.jpg?width=384&height=273&quality=100
# https://images.yogiyo.co.kr/image/yogiyo/PARTNER_FR_IMG/%EC%B2%AD%EB%85%84%ED%94%BC%EC%9E%90/2024-07-09/%EC%A0%9C%ED%9C%B4FR_20240709_%EC%B2%AD%EB%85%84%ED%94%BC%EC%9E%90_%ED%95%AB%EC%86%8C%EC%8A%A4_1080x640.jpg?width=384&height=273&quality=100
# image/ic_photomenu_default.png
# 29
# image/ic_photomenu_default.png
# https://images.yogiyo.co.kr/image/yogiyo/PARTNER_FR_IMG/%EC%B2%AD%EB%85%84%ED%94%BC%EC%9E%90/2024-07-09/%EC%A0%9C%ED%9C%B4FR_20240709_%EC%B2%AD%EB%85%84%ED%94%BC%EC%9E%90_%EB%A6%AC%EC%96%BC%EC%B9%98%EC%A6%88_1080x640.jpg?width=384&height=273&quality=100
# https://images.yogiyo.co.kr/image/yogiyo/PARTNER_FR_IMG/%EC%B2%AD%EB%85%84%ED%94%BC%EC%9E%90/2024-07-09/%EC%A0%9C%ED%9C%B4FR_20240709_%EC%B2%AD%EB%85%84%ED%94%BC%EC%9E%90_%EB%82%98%EC%B4%88%EC%B9%98%EC%A6%88%EA%B0%90%EC%9E%90%ED%8A%80%EA%B9%80_1080x640.jpg?width=384&height=273&quality=100
# https://images.yogiyo.co.kr/image/yogiyo/PARTNER_FR_IMG/%EC%B2%AD%EB%85%84%ED%94%BC%EC%9E%90/2024-07-09/%EC%A0%9C%ED%9C%B4FR_20240709_%EC%B2%AD%EB%85%84%ED%94%BC%EC%9E%90_%EC%8A%88%ED%8D%BC%EC%8A%88%ED%94%84%EB%A6%BC_1080x640.jpg?width=384&height=273&quality=100
# https://images.yogiyo.co.kr/image/yogiyo/PARTNER_FR_IMG/%EC%B2%AD%EB%85%84%ED%94%BC%EC%9E%90/2024-07-09/%EC%A0%9C%ED%9C%B4FR_20240709_%EC%B2%AD%EB%85%84%ED%94%BC%EC%9E%90_K%EB%A1%9C%EC%A0%9C%ED%8C%8C%EC%8A%A4%ED%83%80_1080x640.jpg?width=384&height=273&quality=100
# https://images.yogiyo.co.kr/image/yogiyo/PARTNER_FR_IMG/%EC%B2%AD%EB%85%84%ED%94%BC%EC%9E%90/2024-07-09/%EC%A0%9C%ED%9C%B4FR_20240709_%EC%B2%AD%EB%85%84%ED%94%BC%EC%9E%90_%EC%B2%AD%EB%85%84%EB%84%88%EA%B2%9F15%EA%B0%9C_1080x640.jpg?width=384&height=273&quality=100
# https://images.yogiyo.co.kr/image/yogiyo/PARTNER_FR_IMG/%EC%B2%AD%EB%85%84%ED%94%BC%EC%9E%90/2024-07-09/%EC%A0%9C%ED%9C%B4FR_20240709_%EC%B2%AD%EB%85%84%ED%94%BC%EC%9E%90_%EC%BD%94%EC%B9%B4%EC%BD%9C%EB%9D%BC%EC%A0%9C%EB%A1%9C1250mL_1080x640.jpg?width=384&height=273&quality=100
# https://images.yogiyo.co.kr/image/yogiyo/PARTNER_FR_IMG/%EC%B2%AD%EB%85%84%ED%94%BC%EC%9E%90/2024-07-09/%EC%A0%9C%ED%9C%B4FR_20240709_%EC%B2%AD%EB%85%84%ED%94%BC%EC%9E%90_%EC%98%A4%EB%A6%AC%EC%A7%80%EB%84%90Ln%EC%82%AC%EC%9D%B4%EB%93%9C%EB%A9%94%EB%89%B4-%ED%83%9D1n%EC%9D%8C%EB%A3%8C1250mL_1080x640.jpg?width=384&height=273&quality=100
# https://images.yogiyo.co.kr/image/yogiyo/PARTNER_FR_IMG/%EC%B2%AD%EB%85%84%ED%94%BC%EC%9E%90/2024-07-09/%EC%A0%9C%ED%9C%B4FR_20240709_%EC%B2%AD%EB%85%84%ED%94%BC%EC%9E%90_%EC%B9%98%EC%A6%88%EC%B6%94%EA%B0%80-80g_1080x640.jpg?width=384&height=273&quality=100
# https://images.yogiyo.co.kr/image/yogiyo/PARTNER_FR_IMG/%EC%B2%AD%EB%85%84%ED%94%BC%EC%9E%90/2024-07-09/%EC%A0%9C%ED%9C%B4FR_20240709_%EC%B2%AD%EB%85%84%ED%94%BC%EC%9E%90_%EC%98%A4%EB%A6%AC%EC%A7%80%EB%84%90Ln%EC%98%A4%EB%A6%AC%EC%A7%80%EB%84%90L_1080x640.jpg?width=384&height=273&quality=100
# https://images.yogiyo.co.kr/image/yogiyo/PARTNER_FR_IMG/%EC%B2%AD%EB%85%84%ED%94%BC%EC%9E%90/2025-02-28/%EC%A0%9C%ED%9C%B4FR_20250227_%EC%B2%AD%EB%85%84%ED%94%BC%EC%9E%90_%EB%82%98%EB%A7%8C%EC%9D%98-%EC%82%AC%EC%83%89%ED%94%BC%EC%9E%90L_1080x640.jpg?width=384&height=273&quality=100
# https://images.yogiyo.co.kr/image/yogiyo/PARTNER_FR_IMG/%EC%B2%AD%EB%85%84%ED%94%BC%EC%9E%90/2024-07-09/%EC%A0%9C%ED%9C%B4FR_20240709_%EC%B2%AD%EB%85%84%ED%94%BC%EC%9E%90_%ED%95%98%EC%99%80%EC%9D%B4%EC%95%88_1080x640.jpg?width=384&height=273&quality=100
# https://images.yogiyo.co.kr/image/yogiyo/PARTNER_FR_IMG/%EC%B2%AD%EB%85%84%ED%94%BC%EC%9E%90/2024-07-09/%EC%A0%9C%ED%9C%B4FR_20240709_%EC%B2%AD%EB%85%84%ED%94%BC%EC%9E%90_%EC%BD%94%EC%B9%B4%EC%BD%9C%EB%9D%BC500ML_1080x640.jpg?width=384&height=273&quality=100
# https://images.yogiyo.co.kr/image/yogiyo/PARTNER_FR_IMG/%EC%B2%AD%EB%85%84%ED%94%BC%EC%9E%90/2024-07-09/%EC%A0%9C%ED%9C%B4FR_20240709_%EC%B2%AD%EB%85%84%ED%94%BC%EC%9E%90_%EC%BD%94%EC%B9%B4%EC%BD%9C%EB%9D%BC%EC%A0%9C%EB%A1%9C500ML_1080x640.jpg?width=384&height=273&quality=100
# https://images.yogiyo.co.kr/image/yogiyo/PARTNER_FR_IMG/%EC%B2%AD%EB%85%84%ED%94%BC%EC%9E%90/2024-12-13/%EC%A0%9C%ED%9C%B4FR_20241212_%EC%B2%AD%EB%85%84%ED%94%BC%EC%9E%90_%EB%A9%9C%ED%8C%85-%EA%B3%A0%EA%B5%AC%EB%A7%88-%ED%94%BC%EC%9E%90_1080x640.jpg?width=384&height=273&quality=100
# https://images.yogiyo.co.kr/image/yogiyo/PARTNER_FR_IMG/%EC%B2%AD%EB%85%84%ED%94%BC%EC%9E%90/2024-07-09/%EC%A0%9C%ED%9C%B4FR_20240709_%EC%B2%AD%EB%85%84%ED%94%BC%EC%9E%90_%EC%98%A4%EB%A6%AC%EC%A7%80%EB%84%90Ln_%EA%B5%AD%EB%82%B4%EC%82%B0_%EC%98%A4%EB%B8%90%EB%B2%A0%EC%9D%B4%ED%81%AC%EC%B9%98%ED%82%A8-%ED%83%9D1n%EC%9D%8C%EB%A3%8C_1080x640.jpg?width=384&height=273&quality=100
# https://images.yogiyo.co.kr/image/yogiyo/PARTNER_FR_IMG/%EC%B2%AD%EB%85%84%ED%94%BC%EC%9E%90/2024-07-09/%EC%A0%9C%ED%9C%B4FR_20240709_%EC%B2%AD%EB%85%84%ED%94%BC%EC%9E%90_%EC%B2%AD%EC%96%91%EB%A7%88%EC%9A%94%EC%86%8C%EC%8A%A4_1080x640.jpg?width=384&height=273&quality=100
# https://images.yogiyo.co.kr/image/yogiyo/PARTNER_FR_IMG/%EC%B2%AD%EB%85%84%ED%94%BC%EC%9E%90/2024-07-09/%EC%A0%9C%ED%9C%B4FR_20240709_%EC%B2%AD%EB%85%84%ED%94%BC%EC%9E%90_%EC%8B%A0%EB%A9%94%EB%89%B4_%EB%A9%94%EA%B0%80%EC%89%AC%EB%A6%BC%ED%94%84%EA%B0%88%EB%A6%AD%ED%81%AC%EB%9F%B0%EC%B9%98_1080x640.jpg?width=384&height=273&quality=100
# https://images.yogiyo.co.kr/image/yogiyo/PARTNER_FR_IMG/%EC%B2%AD%EB%85%84%ED%94%BC%EC%9E%90/2024-07-09/%EC%A0%9C%ED%9C%B4FR_20240709_%EC%B2%AD%EB%85%84%ED%94%BC%EC%9E%90_%EB%A1%9C%EC%A0%9C%EB%B2%A0%EC%9D%B4%EC%BB%A8%EC%8A%A4%ED%8C%8C%EA%B2%8C%ED%8B%B0_1080x640.jpg?width=384&height=273&quality=100
# https://images.yogiyo.co.kr/image/yogiyo/PARTNER_FR_IMG/%EC%B2%AD%EB%85%84%ED%94%BC%EC%9E%90/2024-07-09/%EC%A0%9C%ED%9C%B4FR_20240709_%EC%B2%AD%EB%85%84%ED%94%BC%EC%9E%90_%ED%95%A0%EB%9D%BC%EB%B6%88%EA%B3%A0%EA%B8%B0_1080x640.jpg?width=384&height=273&quality=100
# https://images.yogiyo.co.kr/image/yogiyo/PARTNER_FR_IMG/%EC%B2%AD%EB%85%84%ED%94%BC%EC%9E%90/2024-12-13/%EC%A0%9C%ED%9C%B4FR_20241212_%EC%B2%AD%EB%85%84%ED%94%BC%EC%9E%90_%EC%8B%A0%EB%A9%94%EB%89%B4-%EA%B3%A0%EB%A9%94%EB%B0%80%ED%81%AC-%EC%B9%98%EC%A6%88%EB%B4%89-3%EA%B0%9C_1080x640.jpg?width=384&height=273&quality=100
# https://images.yogiyo.co.kr/image/yogiyo/PARTNER_FR_IMG/%EC%B2%AD%EB%85%84%ED%94%BC%EC%9E%90/2024-07-09/%EC%A0%9C%ED%9C%B4FR_20240709_%EC%B2%AD%EB%85%84%ED%94%BC%EC%9E%90_%EC%8B%A0%EB%A9%94%EB%89%B4_%EB%89%B4%EC%9A%95%EB%B9%84%ED%94%84%EA%B0%88%EB%A6%AD%ED%81%AC%EB%9F%B0%EC%B9%98_1080x640.jpg?width=384&height=273&quality=100
# https://images.yogiyo.co.kr/image/yogiyo/PARTNER_FR_IMG/%EC%B2%AD%EB%85%84%ED%94%BC%EC%9E%90/2024-07-09/%EC%A0%9C%ED%9C%B4FR_20240709_%EC%B2%AD%EB%85%84%ED%94%BC%EC%9E%90_%ED%81%AC%EB%A6%AC%EC%8A%A4%ED%94%BC%EC%A7%81%ED%99%94%EB%B0%94%EB%B2%A0%ED%81%90_1080x640.jpg?width=384&height=273&quality=100
# https://images.yogiyo.co.kr/image/yogiyo/PARTNER_FR_IMG/%EC%B2%AD%EB%85%84%ED%94%BC%EC%9E%90/2024-07-09/%EC%A0%9C%ED%9C%B4FR_20240709_%EC%B2%AD%EB%85%84%ED%94%BC%EC%9E%90_%EB%B2%A0%EC%9D%B4%EC%BB%A8%EC%B6%94%EA%B0%80-24%EA%B0%9C_1080x640.jpg?width=384&height=273&quality=100
# https://images.yogiyo.co.kr/image/yogiyo/PARTNER_FR_IMG/%EC%B2%AD%EB%85%84%ED%94%BC%EC%9E%90/2024-07-09/%EC%A0%9C%ED%9C%B4FR_20240709_%EC%B2%AD%EB%85%84%ED%94%BC%EC%9E%90_%EA%B0%88%EB%A6%AD%EB%94%A5%ED%95%91%EC%86%8C%EC%8A%A4_1080x640.jpg?width=384&height=273&quality=100
# https://images.yogiyo.co.kr/image/yogiyo/PARTNER_FR_IMG/%EC%B2%AD%EB%85%84%ED%94%BC%EC%9E%90/2024-07-09/%EC%A0%9C%ED%9C%B4FR_20240709_%EC%B2%AD%EB%85%84%ED%94%BC%EC%9E%90_%ED%94%84%EB%A6%AC%EB%AF%B8%EC%97%84Rn%EC%B2%AD%ED%94%BC%EC%8A%A4%ED%8B%B1%EC%84%B8%ED%8A%B8_1080x640.jpg?width=384&height=273&quality=100
# https://images.yogiyo.co.kr/image/yogiyo/PARTNER_FR_IMG/%EC%B2%AD%EB%85%84%ED%94%BC%EC%9E%90/2024-07-09/%EC%A0%9C%ED%9C%B4FR_20240709_%EC%B2%AD%EB%85%84%ED%94%BC%EC%9E%90_%EB%B0%98%EB%B0%98%EC%98%A4%EB%A6%AC%EC%A7%80%EB%84%90L_1080x640.jpg?width=384&height=273&quality=100
# https://images.yogiyo.co.kr/image/yogiyo/PARTNER_FR_IMG/%EC%B2%AD%EB%85%84%ED%94%BC%EC%9E%90/2024-07-09/%EC%A0%9C%ED%9C%B4FR_20240709_%EC%B2%AD%EB%85%84%ED%94%BC%EC%9E%90_%EB%B2%A0%EC%9D%B4%EC%BB%A8%EA%B9%8C%EB%A5%B4%EB%B3%B4%EB%82%98%EB%9D%BC_1080x640.jpg?width=384&height=273&quality=100
# https://images.yogiyo.co.kr/image/yogiyo/PARTNER_FR_IMG/%EC%B2%AD%EB%85%84%ED%94%BC%EC%9E%90/2024-12-13/%EC%A0%9C%ED%9C%B4FR_20241212_%EC%B2%AD%EB%85%84%ED%94%BC%EC%9E%90_%EC%8B%A0%EB%A9%94%EB%89%B4-%EB%B0%94%EC%A7%88-%EC%BD%B0%ED%8A%B8%EB%A1%9C%EC%B9%98%EC%A6%88-%ED%94%BC%EC%9E%90_1080x640.jpg?width=384&height=273&quality=100
# https://images.yogiyo.co.kr/image/yogiyo/PARTNER_FR_IMG/%EC%B2%AD%EB%85%84%ED%94%BC%EC%9E%90/2024-07-09/%EC%A0%9C%ED%9C%B4FR_20240709_%EC%B2%AD%EB%85%84%ED%94%BC%EC%9E%90_%EC%97%90%EA%B7%B8%EC%BD%98%ED%94%BC%EC%9E%90_1080x640.jpg?width=384&height=273&quality=100
# https://images.yogiyo.co.kr/image/yogiyo/PARTNER_FR_IMG/%EC%B2%AD%EB%85%84%ED%94%BC%EC%9E%90/2024-07-09/%EC%A0%9C%ED%9C%B4FR_20240709_%EC%B2%AD%EB%85%84%ED%94%BC%EC%9E%90_%ED%94%84%EB%A6%AC%EB%AF%B8%EC%97%84Ln_%EA%B5%AD%EB%82%B4%EC%82%B0_%EC%98%A4%EB%B8%90%EB%B2%A0%EC%9D%B4%ED%81%AC%EC%B9%98%ED%82%A8-%ED%83%9D1n%EC%9D%8C%EB%A3%8C_1080x640.jpg?width=384&height=273&quality=100
# https://images.yogiyo.co.kr/image/yogiyo/PARTNER_FR_IMG/%EC%B2%AD%EB%85%84%ED%94%BC%EC%9E%90/2024-07-09/%EC%A0%9C%ED%9C%B4FR_20240709_%EC%B2%AD%EB%85%84%ED%94%BC%EC%9E%90_%EB%B2%A0%EC%9D%B4%EC%BB%A8%EB%8C%80%ED%8C%8C%ED%81%AC%EB%A6%BC%EC%B9%98%EC%A6%88%EC%8A%A4%ED%8B%B1_1080x640.jpg?width=384&height=273&quality=100
# https://images.yogiyo.co.kr/image/yogiyo/PARTNER_FR_IMG/%EC%B2%AD%EB%85%84%ED%94%BC%EC%9E%90/2024-07-09/%EC%A0%9C%ED%9C%B4FR_20240709_%EC%B2%AD%EB%85%84%ED%94%BC%EC%9E%90_%EA%B5%AD%EB%82%B4%EC%82%B0_%ED%9B%84%EB%9D%BC%EC%9D%B4%EB%93%9C%EC%B9%98%ED%82%A8%EB%8B%AD%EB%8B%A4%EB%A6%AC4%EA%B0%9C_1080x640.jpg?width=384&height=273&quality=100
# https://images.yogiyo.co.kr/image/yogiyo/PARTNER_FR_IMG/%EC%B2%AD%EB%85%84%ED%94%BC%EC%9E%90/2025-02-28/%EC%A0%9C%ED%9C%B4FR_20250227_%EC%B2%AD%EB%85%84%ED%94%BC%EC%9E%90_%EB%B0%98%EB%B0%98-%EC%98%A4%EB%A6%AC%EC%A7%80%EB%84%90R_1080x640.jpg?width=384&height=273&quality=100
# https://images.yogiyo.co.kr/image/yogiyo/PARTNER_FR_IMG/%EC%B2%AD%EB%85%84%ED%94%BC%EC%9E%90/2024-07-09/%EC%A0%9C%ED%9C%B4FR_20240709_%EC%B2%AD%EB%85%84%ED%94%BC%EC%9E%90_%EC%8A%A4%ED%94%84%EB%9D%BC%EC%9D%B4%ED%8A%B8500ML_1080x640.jpg?width=384&height=273&quality=100
# https://images.yogiyo.co.kr/image/yogiyo/PARTNER_FR_IMG/%EC%B2%AD%EB%85%84%ED%94%BC%EC%9E%90/2024-07-09/%EC%A0%9C%ED%9C%B4FR_20240709_%EC%B2%AD%EB%85%84%ED%94%BC%EC%9E%90_%EC%8A%A4%ED%94%84%EB%9D%BC%EC%9D%B4%ED%8A%B81500mL_1080x640.jpg?width=384&height=273&quality=100
# https://images.yogiyo.co.kr/image/yogiyo/PARTNER_FR_IMG/%EC%B2%AD%EB%85%84%ED%94%BC%EC%9E%90/2024-07-09/%EC%A0%9C%ED%9C%B4FR_20240709_%EC%B2%AD%EB%85%84%ED%94%BC%EC%9E%90_%EC%A7%84%EC%A7%9C%EA%B0%90%EC%9E%90%ED%94%BC%EC%9E%90_1080x640.jpg?width=384&height=273&quality=100
# https://images.yogiyo.co.kr/image/yogiyo/PARTNER_FR_IMG/%EC%B2%AD%EB%85%84%ED%94%BC%EC%9E%90/2025-02-28/%EC%A0%9C%ED%9C%B4FR_20250227_%EC%B2%AD%EB%85%84%ED%94%BC%EC%9E%90_%EC%8B%A0%EB%A9%94%EB%89%B4-%EC%98%A5%EC%88%98%EC%88%98%EB%B0%AD-%ED%81%AC%EB%A6%BC%EC%B9%98%EC%A6%88%EC%8A%A4%ED%8B%B1_1080x640.jpg?width=384&height=273&quality=100
# https://images.yogiyo.co.kr/image/yogiyo/PARTNER_FR_IMG/%EC%B2%AD%EB%85%84%ED%94%BC%EC%9E%90/2024-07-09/%EC%A0%9C%ED%9C%B4FR_20240709_%EC%B2%AD%EB%85%84%ED%94%BC%EC%9E%90_%EB%AF%B8%ED%8A%B8%EC%86%8C%EC%8A%A4%EC%8A%A4%ED%8C%8C%EA%B2%8C%ED%8B%B0_1080x640.jpg?width=384&height=273&quality=100
# https://images.yogiyo.co.kr/image/yogiyo/PARTNER_FR_IMG/%EC%B2%AD%EB%85%84%ED%94%BC%EC%9E%90/2024-07-09/%EC%A0%9C%ED%9C%B4FR_20240709_%EC%B2%AD%EB%85%84%ED%94%BC%EC%9E%90_%ED%94%84%EB%A6%AC%EB%AF%B8%EC%97%84Ln%ED%94%84%EB%A6%AC%EB%AF%B8%EC%97%84L_1080x640.jpg?width=384&height=273&quality=100
# https://images.yogiyo.co.kr/image/yogiyo/PARTNER_FR_IMG/%EC%B2%AD%EB%85%84%ED%94%BC%EC%9E%90/2024-07-09/%EC%A0%9C%ED%9C%B4FR_20240709_%EC%B2%AD%EB%85%84%ED%94%BC%EC%9E%90_%ED%95%AB%EC%9C%99%EB%B4%898%EA%B0%9C_1080x640.jpg?width=384&height=273&quality=100
# https://images.yogiyo.co.kr/image/yogiyo/PARTNER_FR_IMG/%EC%B2%AD%EB%85%84%ED%94%BC%EC%9E%90/2024-07-09/%EC%A0%9C%ED%9C%B4FR_20240709_%EC%B2%AD%EB%85%84%ED%94%BC%EC%9E%90_%ED%8C%8C%EB%A7%88%EC%82%B0%EC%B9%98%EC%A6%88_1080x640.jpg?width=384&height=273&quality=100
# https://images.yogiyo.co.kr/image/yogiyo/PARTNER_FR_IMG/%EC%B2%AD%EB%85%84%ED%94%BC%EC%9E%90/2024-07-09/%EC%A0%9C%ED%9C%B4FR_20240709_%EC%B2%AD%EB%85%84%ED%94%BC%EC%9E%90_%EC%95%BC%EC%B1%84%ED%94%BC%EC%9E%90_1080x640.jpg?width=384&height=273&quality=100
# https://images.yogiyo.co.kr/image/yogiyo/PARTNER_FR_IMG/%EC%B2%AD%EB%85%84%ED%94%BC%EC%9E%90/2024-07-09/%EC%A0%9C%ED%9C%B4FR_20240709_%EC%B2%AD%EB%85%84%ED%94%BC%EC%9E%90_%ED%94%BC%ED%81%B4_1080x640.jpg?width=384&height=273&quality=100
# https://images.yogiyo.co.kr/image/yogiyo/PARTNER_FR_IMG/%EC%B2%AD%EB%85%84%ED%94%BC%EC%9E%90/2024-07-09/%EC%A0%9C%ED%9C%B4FR_20240709_%EC%B2%AD%EB%85%84%ED%94%BC%EC%9E%90_%ED%94%84%EB%A6%AC%EB%AF%B8%EC%97%84Ln%EC%82%AC%EC%9D%B4%EB%93%9C%EB%A9%94%EB%89%B4-%ED%83%9D1n%EC%9D%8C%EB%A3%8C1250mL_1080x640.jpg?width=384&height=273&quality=100

# %%
from urllib.parse import unquote, urlparse
import re

def extract_menu_name(url):
    # URL 경로 부분만 가져오기
    path = urlparse(url).path  # 예: /image/.../제휴FR_20240709_청년피자_슈퍼슈프림_1080x640.jpg

    # 한글로 디코딩
    decoded_path = unquote(path)

    # 파일명 추출
    filename = decoded_path.split('/')[-1]  # 제휴FR_20240709_청년피자_슈퍼슈프림_1080x640.jpg

    # 정규표현식으로 메뉴 이름 추출
    match = re.search(r'청년피자_(.+?)_1080x640', filename)
    if match:
        return match.group(1)
    else:
        return None

# %%
from urllib.parse import unquote, urlparse
import re
from itertools import zip_longest

# 메뉴명 추출 함수
def extract_menu_name(url):
    path = urlparse(url).path
    decoded = unquote(path)
    filename = decoded.split('/')[-1]
    match = re.search(r'청년피자_(.+?)_1080x640', filename)
    return match.group(1) if match else "메뉴명 추출 실패"

# 비교 시작
from itertools import zip_longest

for i, (a, div_p) in enumerate(zip_longest(menu, photo_divs)):
    menu_text = a.text.strip() if a else None

    if div_p:
        style = div_p.get('style', '')
        image_urls = re.findall(r"url\('([^']+)'\)", style)
        extracted_name = extract_menu_name(image_urls[0]).strip() if image_urls else None
    else:
        extracted_name = None

    # 비교 결과 출력
    if menu_text != extracted_name:
        print(f"[{i}] ❌ 불일치")
        print(f" - 메뉴     : {menu_text}")
        print(f" - 이미지명 : {extracted_name}")
#     else:
#         print(f"[{i}] ✅ 일치 - '{menu_text}'")
# Out:
# [0] ❌ 불일치
#  - 메뉴     : 나만의 사색피자L
#  - 이미지명 : 나만의-사색피자L
# [1] ❌ 불일치
#  - 메뉴     : 반반 오리지널L
#  - 이미지명 : 반반오리지널L
# [2] ❌ 불일치
#  - 메뉴     : [신메뉴]바질 콰트로치즈 피자
#  - 이미지명 : 신메뉴-바질-콰트로치즈-피자
# [3] ❌ 불일치
#  - 메뉴     : [신메뉴]치즈수플레 미트파이 피자
#  - 이미지명 : 신메뉴-치즈수플레-미트파이-피자
# [4] ❌ 불일치
#  - 메뉴     : 오리지널+[신메뉴]그릴드 와일드 통다리
#  - 이미지명 : 오리지널-신메뉴-그릴드-와일드-통다리
# [6] ❌ 불일치
#  - 메뉴     : 나만의 사색피자L
#  - 이미지명 : 나만의-사색피자L
# [7] ❌ 불일치
#  - 메뉴     : 반반 오리지널L
#  - 이미지명 : 반반오리지널L
# [8] ❌ 불일치
#  - 메뉴     : [신메뉴]바질 콰트로치즈 피자
#  - 이미지명 : 신메뉴-바질-콰트로치즈-피자
# [9] ❌ 불일치
#  - 메뉴     : [신메뉴]치즈수플레 미트파이 피자
#  - 이미지명 : 신메뉴-치즈수플레-미트파이-피자
# [10] ❌ 불일치
#  - 메뉴     : 오리지널+[신메뉴]그릴드 와일드 통다리
#  - 이미지명 : 오리지널-신메뉴-그릴드-와일드-통다리
# [12] ❌ 불일치
#  - 메뉴     : 빅파 불고기 피자
#  - 이미지명 : 빅파-불고기-피자
# [16] ❌ 불일치
#  - 메뉴     : 프리미엄 + 사이드메뉴(택1) + 음료1.25L
#  - 이미지명 : 프리미엄Ln사이드메뉴-택1n음료1250mL
# [17] ❌ 불일치
#  - 메뉴     : 빅파 불고기 피자
#  - 이미지명 : 빅파-불고기-피자
# [21] ❌ 불일치
#  - 메뉴     : 프리미엄 + 사이드메뉴(택1) + 음료1.25L
#  - 이미지명 : 프리미엄Ln사이드메뉴-택1n음료1250mL
# [22] ❌ 불일치
#  - 메뉴     : 나만의 사색피자L
#  - 이미지명 : 나만의-사색피자L
# [23] ❌ 불일치
#  - 메뉴     : 나만의 사색피자L
#  - 이미지명 : 나만의-사색피자L
# [24] ❌ 불일치
#  - 메뉴     : [신메뉴]바질 콰트로치즈 피자
#  - 이미지명 : 신메뉴-바질-콰트로치즈-피자
# [26] ❌ 불일치
#  - 메뉴     : 빅파 불고기 피자
#  - 이미지명 : 빅파-불고기-피자
# [33] ❌ 불일치
#  - 메뉴     : 멜팅 고구마 피자
#  - 이미지명 : 멜팅-고구마-피자
# [36] ❌ 불일치
#  - 메뉴     : [신메뉴]바질 콰트로치즈 피자
#  - 이미지명 : 신메뉴-바질-콰트로치즈-피자
# [38] ❌ 불일치
#  - 메뉴     : 빅파 불고기 피자
#  - 이미지명 : 빅파-불고기-피자
# [45] ❌ 불일치
#  - 메뉴     : 멜팅 고구마 피자
#  - 이미지명 : 멜팅-고구마-피자
# [48] ❌ 불일치
#  - 메뉴     : [신메뉴]치즈수플레 미트파이 피자
#  - 이미지명 : 신메뉴-치즈수플레-미트파이-피자
# [49] ❌ 불일치
#  - 메뉴     : 메가쉬림프 갈릭크런치
#  - 이미지명 : 신메뉴_메가쉬림프갈릭크런치
# [50] ❌ 불일치
#  - 메뉴     : 뉴욕비프 갈릭크런치
#  - 이미지명 : 신메뉴_뉴욕비프갈릭크런치
# [51] ❌ 불일치
#  - 메뉴     : 씨푸드 콘 바스켓
#  - 이미지명 : 씨푸드콘바스켓
# [52] ❌ 불일치
#  - 메뉴     : 크리스피 직화바베큐
#  - 이미지명 : 크리스피직화바베큐
# [53] ❌ 불일치
#  - 메뉴     : [신메뉴]치즈수플레 미트파이 피자
#  - 이미지명 : 신메뉴-치즈수플레-미트파이-피자
# [54] ❌ 불일치
#  - 메뉴     : 메가쉬림프 갈릭크런치
#  - 이미지명 : 신메뉴_메가쉬림프갈릭크런치
# [55] ❌ 불일치
#  - 메뉴     : 뉴욕비프 갈릭크런치
#  - 이미지명 : 신메뉴_뉴욕비프갈릭크런치
# [56] ❌ 불일치
#  - 메뉴     : 씨푸드 콘 바스켓
#  - 이미지명 : 씨푸드콘바스켓
# [57] ❌ 불일치
#  - 메뉴     : 크리스피 직화바베큐
#  - 이미지명 : 크리스피직화바베큐
# [58] ❌ 불일치
#  - 메뉴     : 반반 오리지널L
#  - 이미지명 : 반반오리지널L
# [59] ❌ 불일치
#  - 메뉴     : 반반 오리지널R
#  - 이미지명 : 반반-오리지널R
# [60] ❌ 불일치
#  - 메뉴     : 반반 오리지널L
#  - 이미지명 : 반반오리지널L
# [61] ❌ 불일치
#  - 메뉴     : 반반 오리지널R
#  - 이미지명 : 반반-오리지널R
# [62] ❌ 불일치
#  - 메뉴     : 반반 프리미엄L
#  - 이미지명 : 반반프리미엄L
# [63] ❌ 불일치
#  - 메뉴     : 반반 프리미엄R
#  - 이미지명 : 반반-프리미엄R
# [64] ❌ 불일치
#  - 메뉴     : 반반 프리미엄L
#  - 이미지명 : 반반프리미엄L
# [65] ❌ 불일치
#  - 메뉴     : 반반 프리미엄R
#  - 이미지명 : 반반-프리미엄R
# [66] ❌ 불일치
#  - 메뉴     : 오리지널+[신메뉴]그릴드 와일드 통다리
#  - 이미지명 : 오리지널-신메뉴-그릴드-와일드-통다리
# [67] ❌ 불일치
#  - 메뉴     : 프리미엄+[신메뉴]그릴드 와일드 통다리
#  - 이미지명 : 프리미엄-신메뉴-그릴드-와일드-통다리
# [68] ❌ 불일치
#  - 메뉴     : 오리지널+[국내산]오븐베이크치킨+음료
#  - 이미지명 : 오리지널Ln_국내산_오븐베이크치킨-택1n음료
# [69] ❌ 불일치
#  - 메뉴     : 프리미엄+[국내산]오븐베이크치킨+음료
#  - 이미지명 : 프리미엄Ln_국내산_오븐베이크치킨-택1n음료
# [70] ❌ 불일치
#  - 메뉴     : 오리지널+[신메뉴]그릴드 와일드 통다리
#  - 이미지명 : 오리지널-신메뉴-그릴드-와일드-통다리
# [71] ❌ 불일치
#  - 메뉴     : 프리미엄+[신메뉴]그릴드 와일드 통다리
#  - 이미지명 : 프리미엄-신메뉴-그릴드-와일드-통다리
# [72] ❌ 불일치
#  - 메뉴     : 오리지널+[국내산]오븐베이크치킨+음료
#  - 이미지명 : 오리지널Ln_국내산_오븐베이크치킨-택1n음료
# [73] ❌ 불일치
#  - 메뉴     : 프리미엄+[국내산]오븐베이크치킨+음료
#  - 이미지명 : 프리미엄Ln_국내산_오븐베이크치킨-택1n음료
# [74] ❌ 불일치
#  - 메뉴     : 오리지널 + 청피스틱 세트
#  - 이미지명 : 오리지널Rn청피스틱세트
# [75] ❌ 불일치
#  - 메뉴     : 프리미엄 + 청피스틱 세트
#  - 이미지명 : 프리미엄Rn청피스틱세트
# [76] ❌ 불일치
#  - 메뉴     : 오리지널 + 청피스틱 세트
#  - 이미지명 : 오리지널Rn청피스틱세트
# [77] ❌ 불일치
#  - 메뉴     : 프리미엄 + 청피스틱 세트
#  - 이미지명 : 프리미엄Rn청피스틱세트
# [78] ❌ 불일치
#  - 메뉴     : 프리미엄 + 사이드메뉴(택1) + 음료1.25L
#  - 이미지명 : 프리미엄Ln사이드메뉴-택1n음료1250mL
# [79] ❌ 불일치
#  - 메뉴     : 오리지널 + 사이드메뉴(택1) + 음료1.25L
#  - 이미지명 : 오리지널Ln사이드메뉴-택1n음료1250mL
# [80] ❌ 불일치
#  - 메뉴     : 프리미엄 + 사이드메뉴(택1) + 음료1.25L
#  - 이미지명 : 프리미엄Ln사이드메뉴-택1n음료1250mL
# [81] ❌ 불일치
#  - 메뉴     : 오리지널 + 사이드메뉴(택1) + 음료1.25L
#  - 이미지명 : 오리지널Ln사이드메뉴-택1n음료1250mL
# [82] ❌ 불일치
#  - 메뉴     : 오리지널L + 오리지널L
#  - 이미지명 : 오리지널Ln오리지널L
# [83] ❌ 불일치
#  - 메뉴     : 오리지널L + 프리미엄L
#  - 이미지명 : 오리지널Ln프리미엄L
# [84] ❌ 불일치
#  - 메뉴     : 프리미엄L + 프리미엄L
#  - 이미지명 : 프리미엄Ln프리미엄L
# [85] ❌ 불일치
#  - 메뉴     : 오리지널L + 오리지널L
#  - 이미지명 : 오리지널Ln오리지널L
# [86] ❌ 불일치
#  - 메뉴     : 오리지널L + 프리미엄L
#  - 이미지명 : 오리지널Ln프리미엄L
# [87] ❌ 불일치
#  - 메뉴     : 프리미엄L + 프리미엄L
#  - 이미지명 : 프리미엄Ln프리미엄L
# [88] ❌ 불일치
#  - 메뉴     : [신메뉴]고메밀크 치즈봉 3개
#  - 이미지명 : 신메뉴-고메밀크-치즈봉-3개
# [89] ❌ 불일치
#  - 메뉴     : [신메뉴]크리스피 핫윙 4개
#  - 이미지명 : 신메뉴-크리스피-핫윙-4개
# [90] ❌ 불일치
#  - 메뉴     : [신메뉴]옥수수밭 크림치즈스틱
#  - 이미지명 : 신메뉴-옥수수밭-크림치즈스틱
# [101] ❌ 불일치
#  - 메뉴     : 핫윙봉 5개
#  - 이미지명 : 핫윙봉5개
# [102] ❌ 불일치
#  - 메뉴     : 핫윙봉 8개
#  - 이미지명 : 핫윙봉8개
# [103] ❌ 불일치
#  - 메뉴     : [국내산]오븐베이크치킨
#  - 이미지명 : 국내산_오븐베이크치킨
# [104] ❌ 불일치
#  - 메뉴     : [국내산]후라이드치킨닭다리 2개
#  - 이미지명 : 국내산_후라이드치킨닭다리2개
# [105] ❌ 불일치
#  - 메뉴     : [국내산]후라이드치킨닭다리 4개
#  - 이미지명 : 국내산_후라이드치킨닭다리4개
# [106] ❌ 불일치
#  - 메뉴     : 청년너겟 15개
#  - 이미지명 : 청년너겟15개
# [108] ❌ 불일치
#  - 메뉴     : [신메뉴]고메밀크 치즈봉 3개
#  - 이미지명 : 신메뉴-고메밀크-치즈봉-3개
# [109] ❌ 불일치
#  - 메뉴     : [신메뉴]크리스피 핫윙 4개
#  - 이미지명 : 신메뉴-크리스피-핫윙-4개
# [110] ❌ 불일치
#  - 메뉴     : [신메뉴]옥수수밭 크림치즈스틱
#  - 이미지명 : 신메뉴-옥수수밭-크림치즈스틱
# [121] ❌ 불일치
#  - 메뉴     : 핫윙봉 5개
#  - 이미지명 : 핫윙봉5개
# [122] ❌ 불일치
#  - 메뉴     : 핫윙봉 8개
#  - 이미지명 : 핫윙봉8개
# [123] ❌ 불일치
#  - 메뉴     : [국내산]오븐베이크치킨
#  - 이미지명 : 국내산_오븐베이크치킨
# [124] ❌ 불일치
#  - 메뉴     : [국내산]후라이드치킨닭다리 2개
#  - 이미지명 : 국내산_후라이드치킨닭다리2개
# [125] ❌ 불일치
#  - 메뉴     : [국내산]후라이드치킨닭다리 4개
#  - 이미지명 : 국내산_후라이드치킨닭다리4개
# [126] ❌ 불일치
#  - 메뉴     : 청년너겟 15개
#  - 이미지명 : 청년너겟15개
# [128] ❌ 불일치
#  - 메뉴     : 치즈 추가(80g)
#  - 이미지명 : 치즈추가-80g
# [129] ❌ 불일치
#  - 메뉴     : 페페로니 추가(20개)
#  - 이미지명 : 페페로니추가-20개
# [130] ❌ 불일치
#  - 메뉴     : 베이컨 추가(24개)
#  - 이미지명 : 베이컨추가-24개
# [131] ❌ 불일치
#  - 메뉴     : 옥수수 추가
#  - 이미지명 : 옥수수추가
# [132] ❌ 불일치
#  - 메뉴     : 올리브 추가
#  - 이미지명 : 올리브추가
# [133] ❌ 불일치
#  - 메뉴     : 파인애플 추가
#  - 이미지명 : 파인애플추가
# [134] ❌ 불일치
#  - 메뉴     : 할라피뇨(토핑) 추가
#  - 이미지명 : 할라피뇨_토핑추가
# [135] ❌ 불일치
#  - 메뉴     : 마요네즈 추가
#  - 이미지명 : 마요네즈추가
# [136] ❌ 불일치
#  - 메뉴     : 치즈 추가(80g)
#  - 이미지명 : 치즈추가-80g
# [137] ❌ 불일치
#  - 메뉴     : 페페로니 추가(20개)
#  - 이미지명 : 페페로니추가-20개
# [138] ❌ 불일치
#  - 메뉴     : 베이컨 추가(24개)
#  - 이미지명 : 베이컨추가-24개
# [139] ❌ 불일치
#  - 메뉴     : 옥수수 추가
#  - 이미지명 : 옥수수추가
# [140] ❌ 불일치
#  - 메뉴     : 올리브 추가
#  - 이미지명 : 올리브추가
# [141] ❌ 불일치
#  - 메뉴     : 파인애플 추가
#  - 이미지명 : 파인애플추가
# [142] ❌ 불일치
#  - 메뉴     : 할라피뇨(토핑) 추가
#  - 이미지명 : 할라피뇨_토핑추가
# [143] ❌ 불일치
#  - 메뉴     : 마요네즈 추가
#  - 이미지명 : 마요네즈추가
# [156] ❌ 불일치
#  - 메뉴     : 코카콜라 500ML
#  - 이미지명 : 코카콜라500ML
# [157] ❌ 불일치
#  - 메뉴     : 코카콜라 제로 500ML
#  - 이미지명 : 코카콜라제로500ML
# [158] ❌ 불일치
#  - 메뉴     : 코카콜라 1.25L
#  - 이미지명 : 코카콜라1250mL
# [159] ❌ 불일치
#  - 메뉴     : 코카콜라 제로 1.25L
#  - 이미지명 : 코카콜라제로1250mL
# [160] ❌ 불일치
#  - 메뉴     : 스프라이트 500ML
#  - 이미지명 : 스프라이트500ML
# [161] ❌ 불일치
#  - 메뉴     : 스프라이트 1.5L
#  - 이미지명 : 스프라이트1500mL
# [162] ❌ 불일치
#  - 메뉴     : 코카콜라 500ML
#  - 이미지명 : 코카콜라500ML
# [163] ❌ 불일치
#  - 메뉴     : 코카콜라 제로 500ML
#  - 이미지명 : 코카콜라제로500ML
# [164] ❌ 불일치
#  - 메뉴     : 코카콜라 1.25L
#  - 이미지명 : 코카콜라1250mL
# [165] ❌ 불일치
#  - 메뉴     : 코카콜라 제로 1.25L
#  - 이미지명 : 코카콜라제로1250mL
# [166] ❌ 불일치
#  - 메뉴     : 스프라이트 500ML
#  - 이미지명 : 스프라이트500ML
# [167] ❌ 불일치
#  - 메뉴     : 스프라이트 1.5L
#  - 이미지명 : 스프라이트1500mL
# [168] ❌ 불일치
#  - 메뉴     : 카스 500ml 4캔
#  - 이미지명 : 메뉴명 추출 실패
# [169] ❌ 불일치
#  - 메뉴     : 카스 355ml 1캔
#  - 이미지명 : 메뉴명 추출 실패
# [170] ❌ 불일치
#  - 메뉴     : 카스 355ml 4캔
#  - 이미지명 : 메뉴명 추출 실패
# [171] ❌ 불일치
#  - 메뉴     : 카스 500ml 1캔
#  - 이미지명 : 메뉴명 추출 실패
# [172] ❌ 불일치
#  - 메뉴     : 카스 500ml 4캔
#  - 이미지명 : 메뉴명 추출 실패
# [173] ❌ 불일치
#  - 메뉴     : 카스 355ml 1캔
#  - 이미지명 : 메뉴명 추출 실패
# [174] ❌ 불일치
#  - 메뉴     : 카스 355ml 4캔
#  - 이미지명 : 메뉴명 추출 실패
# [175] ❌ 불일치
#  - 메뉴     : 카스 500ml 1캔
#  - 이미지명 : 메뉴명 추출 실패
