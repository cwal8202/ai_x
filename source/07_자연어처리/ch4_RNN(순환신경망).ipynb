# %%
from IPython.display import display, HTML
display(HTML("""
<style>
div.container{width:86% !important;}
div.cell.code_cell.rendered{width:100%;}
div.CodeMirror {font-family:Consolas; font-size:15pt;}
div.output {font-size:15pt; font-weight:bold;}
div.input {font-family:Consolas; font-size:15pt;}
div.prompt {min-width:70px;}
div#toc-wrapper{padding-top:120px;}
div.text_cell_render ul li{font-size:12pt;padding:5px;}
table.dataframe{font-size:15px;}
</style>
"""))
# Out:
# <style>
# div.container{width:86% !important;}
# div.cell.code_cell.rendered{width:100%;}
# div.CodeMirror {font-family:Consolas; font-size:15pt;}
# div.output {font-size:15pt; font-weight:bold;}
# div.input {font-family:Consolas; font-size:15pt;}
# div.prompt {min-width:70px;}
# div#toc-wrapper{padding-top:120px;}
# div.text_cell_render ul li{font-size:12pt;padding:5px;}
# table.dataframe{font-size:15px;}
# </style>

# %% [markdown]
# **<font size="6" color="red">ch4. RNN(Recurrent Neural Network 순환신경망</font>**
# # 1. 문맥을 이용하여 모델 만들기

# %%
text = """ 경마장에 있는 말이 뛰고 있다
그의 말이 법이다
가는 말이 고와야 오는 말이 곱다"""
# text1 = "장마철이 오고 있다"

# %%
# from keras_preprocessing.text import Tokenizer
# t = Tokenizer()
# t.fit_on_texts([text, text1])
# encoded = t.texts_to_sequences([text, text1])
# print(encoded)
# print(t.word_index)

# %%
# 문자열 리스트를 인덱스 시퀀스로 변환
print(t.texts_to_sequences(['경마장에 말이 있다', '말이 뛴다']))
print(t.texts_to_sequences(['가는 말이 곱다'])[0])
# Out:
# [[3, 1, 2], [1]]
# [8, 1, 11]

# %%
text = """ 경마장에 있는 말이 뛰고 있다
그의 말이 법이다
가는 말이 고와야 오는 말이 곱다"""

# %%
from keras_preprocessing.text import Tokenizer
t = Tokenizer()
t.fit_on_texts([text])
encoded = t.texts_to_sequences([text])
print(encoded)
print(t.word_index)
# Out:
# [[2, 3, 1, 4, 5, 6, 1, 7, 8, 1, 9, 10, 1, 11]]
# {'말이': 1, '경마장에': 2, '있는': 3, '뛰고': 4, '있다': 5, '그의': 6, '법이다': 7, '가는': 8, '고와야': 9, '오는': 10, '곱다': 11}

# %%
for key, value in t.word_index.items():
    print(key, value)
# Out:
# 말이 1
# 경마장에 2
# 있는 3
# 뛰고 4
# 있다 5
# 그의 6
# 법이다 7
# 가는 8
# 고와야 9
# 오는 10
# 곱다 11

# %%
# 학습을 시키기 위해 ['경마장에 있는', '경마장에 있는 말이', ...]
sequences = []
for line in text.split('\n'):
    print('원문장 :', line)
    encoded = t.texts_to_sequences([line])[0]
    print('encoded된 문장 :', encoded)
    for i in range(0, len(encoded)-1): # i: 시작index
          for j in range(i+2, len(encoded)+1): # j: 끝나는 index 바로 뒤
              sequences.append(encoded[i:j])
print('sequences와 해석 출력')
for sequence in sequences:
    for word_seq in sequence:
        for word, id in t.word_index.items():
            if word_seq==id:
                print("{}:{}".format(word_seq, word), end=' ')
                break
    print()
# Out:
# 원문장 :  경마장에 있는 말이 뛰고 있다
# encoded된 문장 : [2, 3, 1, 4, 5]
# 원문장 : 그의 말이 법이다
# encoded된 문장 : [6, 1, 7]
# 원문장 : 가는 말이 고와야 오는 말이 곱다
# encoded된 문장 : [8, 1, 9, 10, 1, 11]
# sequences와 해석 출력
# 2:경마장에 3:있는
# 2:경마장에 3:있는 1:말이
# 2:경마장에 3:있는 1:말이 4:뛰고
# 2:경마장에 3:있는 1:말이 4:뛰고 5:있다
# 3:있는 1:말이
# 3:있는 1:말이 4:뛰고
# 3:있는 1:말이 4:뛰고 5:있다
# 1:말이 4:뛰고
# 1:말이 4:뛰고 5:있다
# 4:뛰고 5:있다
# 6:그의 1:말이
# 6:그의 1:말이 7:법이다
# 1:말이 7:법이다
# 8:가는 1:말이
# 8:가는 1:말이 9:고와야
# 8:가는 1:말이 9:고와야 10:오는
# 8:가는 1:말이 9:고와야 10:오는 1:말이
# 8:가는 1:말이 9:고와야 10:오는 1:말이 11:곱다
# 1:말이 9:고와야
# 1:말이 9:고와야 10:오는
# 1:말이 9:고와야 10:오는 1:말이
# 1:말이 9:고와야 10:오는 1:말이 11:곱다
# 9:고와야 10:오는
# 9:고와야 10:오는 1:말이
# 9:고와야 10:오는 1:말이 11:곱다
# 10:오는 1:말이
# 10:오는 1:말이 11:곱다
# 1:말이 11:곱다

# %%
print([len(sequence) for sequence in sequences])
my_len = max(len(sequence) for sequence in sequences)
# Out:
# [2, 3, 4, 5, 2, 3, 4, 2, 3, 2, 2, 3, 2, 2, 3, 4, 5, 6, 2, 3, 4, 5, 2, 3, 4, 2, 3, 2]

# %%
# sequences를 훈련 가능하도록 모두 6개로 조정
from tensorflow.keras.preprocessing.sequence import pad_sequences
padded_sequences = pad_sequences(sequences=sequences,
                                maxlen=my_len,
#                                 padding='post',
                                padding='pre')
padded_sequences.shape, type(padded_sequences)
padded_sequences
# Out:
# array([[ 0,  0,  0,  0,  2,  3],
#        [ 0,  0,  0,  2,  3,  1],
#        [ 0,  0,  2,  3,  1,  4],
#        [ 0,  2,  3,  1,  4,  5],
#        [ 0,  0,  0,  0,  3,  1],
#        [ 0,  0,  0,  3,  1,  4],
#        [ 0,  0,  3,  1,  4,  5],
#        [ 0,  0,  0,  0,  1,  4],
#        [ 0,  0,  0,  1,  4,  5],
#        [ 0,  0,  0,  0,  4,  5],
#        [ 0,  0,  0,  0,  6,  1],
#        [ 0,  0,  0,  6,  1,  7],
#        [ 0,  0,  0,  0,  1,  7],
#        [ 0,  0,  0,  0,  8,  1],
#        [ 0,  0,  0,  8,  1,  9],
#        [ 0,  0,  8,  1,  9, 10],
#        [ 0,  8,  1,  9, 10,  1],
#        [ 8,  1,  9, 10,  1, 11],
#        [ 0,  0,  0,  0,  1,  9],
#        [ 0,  0,  0,  1,  9, 10],
#        [ 0,  0,  1,  9, 10,  1],
#        [ 0,  1,  9, 10,  1, 11],
#        [ 0,  0,  0,  0,  9, 10],
#        [ 0,  0,  0,  9, 10,  1],
#        [ 0,  0,  9, 10,  1, 11],
#        [ 0,  0,  0,  0, 10,  1],
#        [ 0,  0,  0, 10,  1, 11],
#        [ 0,  0,  0,  0,  1, 11]])

# %%
# 독립변수(X)와 타겟변수(y)로 분리
X = padded_sequences[:, :-1]
y = padded_sequences[:, -1]
y
# Out:
# array([ 3,  1,  4,  5,  1,  4,  5,  4,  5,  5,  1,  7,  7,  1,  9, 10,  1,
#        11,  9, 10,  1, 11, 10,  1, 11,  1, 11, 11])

# %%
# X를 임베딩 작업할 때 필요한 입력 bit 수 (단어수+1)
input_dim = len(t.word_index)+1
input_dim
# Out:
# 12

# %%
# y의 원핫인코딩
from tensorflow.keras.utils import to_categorical
Y = to_categorical(y, input_dim)
X.shape, Y.shape, input_dim
# Out:
# ((28, 5), (28, 12), 12)

# %%
# 2. 모델 생성하기
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Embedding # Xi의 원핫인코딩한 희소행렬 변환
from tensorflow.keras.layers import SimpleRNN, Dense
import matplotlib.pyplot as plt

model = Sequential()
model.add(Embedding(input_dim=input_dim, # 12개로 원핫인코딩
                    output_dim=10, # 임베딩 출력의 갯수
                    input_length=X.shape[1] # 입력(X)의 수
                   ))
model.add(SimpleRNN(units=32))
model.add(Dense(12, activation='softmax'))
print(model.summary())
# 3. 모델 학습 과정 설정
model.compile(loss='categorical_crossentropy', optimizer='adam', metrics=['accuracy'])
# 4. 모델 학습시키기
hist = model.fit(X, Y, epochs=300, verbose=2)
# Out:
# Model: "sequential_5"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  embedding_5 (Embedding)     (None, 5, 10)             120
#
#  simple_rnn_5 (SimpleRNN)    (None, 32)                1376
#
#  dense_5 (Dense)             (None, 12)                396
#
# =================================================================
# Total params: 1,892
# Trainable params: 1,892
# Non-trainable params: 0
# _________________________________________________________________
# None
# Epoch 1/300
# 1/1 - 1s - loss: 2.4710 - accuracy: 0.2857 - 964ms/epoch - 964ms/step
# Epoch 2/300
# 1/1 - 0s - loss: 2.4593 - accuracy: 0.3214 - 4ms/epoch - 4ms/step
# Epoch 3/300
# 1/1 - 0s - loss: 2.4474 - accuracy: 0.3571 - 4ms/epoch - 4ms/step
# Epoch 4/300
# 1/1 - 0s - loss: 2.4352 - accuracy: 0.3214 - 4ms/epoch - 4ms/step
# Epoch 5/300
# 1/1 - 0s - loss: 2.4225 - accuracy: 0.3214 - 5ms/epoch - 5ms/step
# Epoch 6/300
# 1/1 - 0s - loss: 2.4094 - accuracy: 0.3214 - 5ms/epoch - 5ms/step
# Epoch 7/300
# 1/1 - 0s - loss: 2.3957 - accuracy: 0.3214 - 5ms/epoch - 5ms/step
# Epoch 8/300
# 1/1 - 0s - loss: 2.3814 - accuracy: 0.3214 - 5ms/epoch - 5ms/step
# Epoch 9/300
# 1/1 - 0s - loss: 2.3665 - accuracy: 0.3214 - 5ms/epoch - 5ms/step
# Epoch 10/300
# 1/1 - 0s - loss: 2.3508 - accuracy: 0.3214 - 4ms/epoch - 4ms/step
# Epoch 11/300
# 1/1 - 0s - loss: 2.3344 - accuracy: 0.3214 - 5ms/epoch - 5ms/step
# Epoch 12/300
# 1/1 - 0s - loss: 2.3173 - accuracy: 0.2857 - 5ms/epoch - 5ms/step
# Epoch 13/300
# 1/1 - 0s - loss: 2.2995 - accuracy: 0.2857 - 15ms/epoch - 15ms/step
# Epoch 14/300
# 1/1 - 0s - loss: 2.2810 - accuracy: 0.2857 - 8ms/epoch - 8ms/step
# Epoch 15/300
# 1/1 - 0s - loss: 2.2619 - accuracy: 0.2857 - 4ms/epoch - 4ms/step
# Epoch 16/300
# 1/1 - 0s - loss: 2.2422 - accuracy: 0.2857 - 5ms/epoch - 5ms/step
# Epoch 17/300
# 1/1 - 0s - loss: 2.2222 - accuracy: 0.2857 - 5ms/epoch - 5ms/step
# Epoch 18/300
# 1/1 - 0s - loss: 2.2020 - accuracy: 0.2857 - 4ms/epoch - 4ms/step
# Epoch 19/300
# 1/1 - 0s - loss: 2.1818 - accuracy: 0.2857 - 5ms/epoch - 5ms/step
# Epoch 20/300
# 1/1 - 0s - loss: 2.1618 - accuracy: 0.2857 - 5ms/epoch - 5ms/step
# Epoch 21/300
# 1/1 - 0s - loss: 2.1424 - accuracy: 0.2857 - 5ms/epoch - 5ms/step
# Epoch 22/300
# 1/1 - 0s - loss: 2.1238 - accuracy: 0.2857 - 5ms/epoch - 5ms/step
# Epoch 23/300
# 1/1 - 0s - loss: 2.1062 - accuracy: 0.2857 - 4ms/epoch - 4ms/step
# Epoch 24/300
# 1/1 - 0s - loss: 2.0898 - accuracy: 0.2857 - 5ms/epoch - 5ms/step
# Epoch 25/300
# 1/1 - 0s - loss: 2.0746 - accuracy: 0.2857 - 4ms/epoch - 4ms/step
# Epoch 26/300
# 1/1 - 0s - loss: 2.0607 - accuracy: 0.2857 - 5ms/epoch - 5ms/step
# Epoch 27/300
# 1/1 - 0s - loss: 2.0478 - accuracy: 0.2857 - 4ms/epoch - 4ms/step
# Epoch 28/300
# 1/1 - 0s - loss: 2.0356 - accuracy: 0.2857 - 4ms/epoch - 4ms/step
# Epoch 29/300
# 1/1 - 0s - loss: 2.0240 - accuracy: 0.2857 - 4ms/epoch - 4ms/step
# Epoch 30/300
# 1/1 - 0s - loss: 2.0125 - accuracy: 0.2857 - 6ms/epoch - 6ms/step
# Epoch 31/300
# 1/1 - 0s - loss: 2.0011 - accuracy: 0.2857 - 6ms/epoch - 6ms/step
# Epoch 32/300
# 1/1 - 0s - loss: 1.9896 - accuracy: 0.2857 - 6ms/epoch - 6ms/step
# Epoch 33/300
# 1/1 - 0s - loss: 1.9781 - accuracy: 0.2857 - 5ms/epoch - 5ms/step
# Epoch 34/300
# 1/1 - 0s - loss: 1.9666 - accuracy: 0.2857 - 7ms/epoch - 7ms/step
# Epoch 35/300
# 1/1 - 0s - loss: 1.9553 - accuracy: 0.2857 - 5ms/epoch - 5ms/step
# Epoch 36/300
# 1/1 - 0s - loss: 1.9445 - accuracy: 0.2857 - 5ms/epoch - 5ms/step
# Epoch 37/300
# 1/1 - 0s - loss: 1.9342 - accuracy: 0.2857 - 4ms/epoch - 4ms/step
# Epoch 38/300
# 1/1 - 0s - loss: 1.9245 - accuracy: 0.2857 - 4ms/epoch - 4ms/step
# Epoch 39/300
# 1/1 - 0s - loss: 1.9157 - accuracy: 0.2857 - 4ms/epoch - 4ms/step
# Epoch 40/300
# 1/1 - 0s - loss: 1.9075 - accuracy: 0.2857 - 5ms/epoch - 5ms/step
# Epoch 41/300
# 1/1 - 0s - loss: 1.9000 - accuracy: 0.2857 - 5ms/epoch - 5ms/step
# Epoch 42/300
# 1/1 - 0s - loss: 1.8930 - accuracy: 0.3214 - 4ms/epoch - 4ms/step
# Epoch 43/300
# 1/1 - 0s - loss: 1.8863 - accuracy: 0.3214 - 4ms/epoch - 4ms/step
# Epoch 44/300
# 1/1 - 0s - loss: 1.8798 - accuracy: 0.3214 - 4ms/epoch - 4ms/step
# Epoch 45/300
# 1/1 - 0s - loss: 1.8734 - accuracy: 0.3214 - 4ms/epoch - 4ms/step
# Epoch 46/300
# 1/1 - 0s - loss: 1.8669 - accuracy: 0.3214 - 5ms/epoch - 5ms/step
# Epoch 47/300
# 1/1 - 0s - loss: 1.8602 - accuracy: 0.3571 - 5ms/epoch - 5ms/step
# Epoch 48/300
# 1/1 - 0s - loss: 1.8534 - accuracy: 0.3571 - 5ms/epoch - 5ms/step
# Epoch 49/300
# 1/1 - 0s - loss: 1.8466 - accuracy: 0.3571 - 5ms/epoch - 5ms/step
# Epoch 50/300
# 1/1 - 0s - loss: 1.8396 - accuracy: 0.3571 - 4ms/epoch - 4ms/step
# Epoch 51/300
# 1/1 - 0s - loss: 1.8327 - accuracy: 0.3571 - 4ms/epoch - 4ms/step
# Epoch 52/300
# 1/1 - 0s - loss: 1.8257 - accuracy: 0.3571 - 3ms/epoch - 3ms/step
# Epoch 53/300
# 1/1 - 0s - loss: 1.8187 - accuracy: 0.3571 - 3ms/epoch - 3ms/step
# Epoch 54/300
# 1/1 - 0s - loss: 1.8116 - accuracy: 0.3571 - 4ms/epoch - 4ms/step
# Epoch 55/300
# 1/1 - 0s - loss: 1.8045 - accuracy: 0.3571 - 3ms/epoch - 3ms/step
# Epoch 56/300
# 1/1 - 0s - loss: 1.7972 - accuracy: 0.3571 - 4ms/epoch - 4ms/step
# Epoch 57/300
# 1/1 - 0s - loss: 1.7896 - accuracy: 0.3571 - 4ms/epoch - 4ms/step
# Epoch 58/300
# 1/1 - 0s - loss: 1.7818 - accuracy: 0.3571 - 3ms/epoch - 3ms/step
# Epoch 59/300
# 1/1 - 0s - loss: 1.7737 - accuracy: 0.3929 - 3ms/epoch - 3ms/step
# Epoch 60/300
# 1/1 - 0s - loss: 1.7652 - accuracy: 0.4286 - 4ms/epoch - 4ms/step
# Epoch 61/300
# 1/1 - 0s - loss: 1.7564 - accuracy: 0.4286 - 4ms/epoch - 4ms/step
# Epoch 62/300
# 1/1 - 0s - loss: 1.7473 - accuracy: 0.4286 - 3ms/epoch - 3ms/step
# Epoch 63/300
# 1/1 - 0s - loss: 1.7378 - accuracy: 0.4286 - 3ms/epoch - 3ms/step
# Epoch 64/300
# 1/1 - 0s - loss: 1.7281 - accuracy: 0.4286 - 4ms/epoch - 4ms/step
# Epoch 65/300
# 1/1 - 0s - loss: 1.7182 - accuracy: 0.4286 - 4ms/epoch - 4ms/step
# Epoch 66/300
# 1/1 - 0s - loss: 1.7080 - accuracy: 0.4643 - 3ms/epoch - 3ms/step
# Epoch 67/300
# 1/1 - 0s - loss: 1.6975 - accuracy: 0.4643 - 3ms/epoch - 3ms/step
# Epoch 68/300
# 1/1 - 0s - loss: 1.6867 - accuracy: 0.5000 - 3ms/epoch - 3ms/step
# Epoch 69/300
# 1/1 - 0s - loss: 1.6757 - accuracy: 0.5000 - 4ms/epoch - 4ms/step
# Epoch 70/300
# 1/1 - 0s - loss: 1.6644 - accuracy: 0.5000 - 3ms/epoch - 3ms/step
# Epoch 71/300
# 1/1 - 0s - loss: 1.6529 - accuracy: 0.5000 - 4ms/epoch - 4ms/step
# Epoch 72/300
# 1/1 - 0s - loss: 1.6411 - accuracy: 0.5000 - 4ms/epoch - 4ms/step
# Epoch 73/300
# 1/1 - 0s - loss: 1.6291 - accuracy: 0.5000 - 3ms/epoch - 3ms/step
# Epoch 74/300
# 1/1 - 0s - loss: 1.6169 - accuracy: 0.5000 - 3ms/epoch - 3ms/step
# Epoch 75/300
# 1/1 - 0s - loss: 1.6045 - accuracy: 0.5000 - 3ms/epoch - 3ms/step
# Epoch 76/300
# 1/1 - 0s - loss: 1.5919 - accuracy: 0.5000 - 4ms/epoch - 4ms/step
# Epoch 77/300
# 1/1 - 0s - loss: 1.5792 - accuracy: 0.5357 - 5ms/epoch - 5ms/step
# Epoch 78/300
# 1/1 - 0s - loss: 1.5663 - accuracy: 0.5357 - 4ms/epoch - 4ms/step
# Epoch 79/300
# 1/1 - 0s - loss: 1.5532 - accuracy: 0.5357 - 4ms/epoch - 4ms/step
# Epoch 80/300
# 1/1 - 0s - loss: 1.5400 - accuracy: 0.5357 - 4ms/epoch - 4ms/step
# Epoch 81/300
# 1/1 - 0s - loss: 1.5267 - accuracy: 0.5357 - 4ms/epoch - 4ms/step
# Epoch 82/300
# 1/1 - 0s - loss: 1.5132 - accuracy: 0.5357 - 4ms/epoch - 4ms/step
# Epoch 83/300
# 1/1 - 0s - loss: 1.4996 - accuracy: 0.5357 - 4ms/epoch - 4ms/step
# Epoch 84/300
# 1/1 - 0s - loss: 1.4859 - accuracy: 0.5357 - 4ms/epoch - 4ms/step
# Epoch 85/300
# 1/1 - 0s - loss: 1.4721 - accuracy: 0.5357 - 4ms/epoch - 4ms/step
# Epoch 86/300
# 1/1 - 0s - loss: 1.4582 - accuracy: 0.5357 - 4ms/epoch - 4ms/step
# Epoch 87/300
# 1/1 - 0s - loss: 1.4442 - accuracy: 0.5357 - 4ms/epoch - 4ms/step
# Epoch 88/300
# 1/1 - 0s - loss: 1.4302 - accuracy: 0.5357 - 4ms/epoch - 4ms/step
# Epoch 89/300
# 1/1 - 0s - loss: 1.4162 - accuracy: 0.5357 - 3ms/epoch - 3ms/step
# Epoch 90/300
# 1/1 - 0s - loss: 1.4020 - accuracy: 0.5357 - 4ms/epoch - 4ms/step
# Epoch 91/300
# 1/1 - 0s - loss: 1.3879 - accuracy: 0.5357 - 3ms/epoch - 3ms/step
# Epoch 92/300
# 1/1 - 0s - loss: 1.3737 - accuracy: 0.5357 - 3ms/epoch - 3ms/step
# Epoch 93/300
# 1/1 - 0s - loss: 1.3596 - accuracy: 0.5357 - 4ms/epoch - 4ms/step
# Epoch 94/300
# 1/1 - 0s - loss: 1.3454 - accuracy: 0.5357 - 3ms/epoch - 3ms/step
# Epoch 95/300
# 1/1 - 0s - loss: 1.3313 - accuracy: 0.5357 - 4ms/epoch - 4ms/step
# Epoch 96/300
# 1/1 - 0s - loss: 1.3172 - accuracy: 0.5357 - 3ms/epoch - 3ms/step
# Epoch 97/300
# 1/1 - 0s - loss: 1.3031 - accuracy: 0.6071 - 3ms/epoch - 3ms/step
# Epoch 98/300
# 1/1 - 0s - loss: 1.2891 - accuracy: 0.6071 - 4ms/epoch - 4ms/step
# Epoch 99/300
# 1/1 - 0s - loss: 1.2752 - accuracy: 0.6071 - 3ms/epoch - 3ms/step
# Epoch 100/300
# 1/1 - 0s - loss: 1.2613 - accuracy: 0.6071 - 3ms/epoch - 3ms/step
# Epoch 101/300
# 1/1 - 0s - loss: 1.2475 - accuracy: 0.6429 - 3ms/epoch - 3ms/step
# Epoch 102/300
# 1/1 - 0s - loss: 1.2338 - accuracy: 0.6429 - 4ms/epoch - 4ms/step
# Epoch 103/300
# 1/1 - 0s - loss: 1.2201 - accuracy: 0.6786 - 3ms/epoch - 3ms/step
# Epoch 104/300
# 1/1 - 0s - loss: 1.2066 - accuracy: 0.6786 - 3ms/epoch - 3ms/step
# Epoch 105/300
# 1/1 - 0s - loss: 1.1932 - accuracy: 0.6786 - 4ms/epoch - 4ms/step
# Epoch 106/300
# 1/1 - 0s - loss: 1.1799 - accuracy: 0.6786 - 3ms/epoch - 3ms/step
# Epoch 107/300
# 1/1 - 0s - loss: 1.1667 - accuracy: 0.6786 - 4ms/epoch - 4ms/step
# Epoch 108/300
# 1/1 - 0s - loss: 1.1536 - accuracy: 0.6786 - 4ms/epoch - 4ms/step
# Epoch 109/300
# 1/1 - 0s - loss: 1.1406 - accuracy: 0.6786 - 4ms/epoch - 4ms/step
# Epoch 110/300
# 1/1 - 0s - loss: 1.1278 - accuracy: 0.6786 - 3ms/epoch - 3ms/step
# Epoch 111/300
# 1/1 - 0s - loss: 1.1151 - accuracy: 0.6786 - 3ms/epoch - 3ms/step
# Epoch 112/300
# 1/1 - 0s - loss: 1.1025 - accuracy: 0.6786 - 3ms/epoch - 3ms/step
# Epoch 113/300
# 1/1 - 0s - loss: 1.0900 - accuracy: 0.6786 - 4ms/epoch - 4ms/step
# Epoch 114/300
# 1/1 - 0s - loss: 1.0777 - accuracy: 0.6786 - 3ms/epoch - 3ms/step
# Epoch 115/300
# 1/1 - 0s - loss: 1.0656 - accuracy: 0.6786 - 5ms/epoch - 5ms/step
# Epoch 116/300
# 1/1 - 0s - loss: 1.0535 - accuracy: 0.7143 - 3ms/epoch - 3ms/step
# Epoch 117/300
# 1/1 - 0s - loss: 1.0416 - accuracy: 0.7143 - 4ms/epoch - 4ms/step
# Epoch 118/300
# 1/1 - 0s - loss: 1.0299 - accuracy: 0.7143 - 4ms/epoch - 4ms/step
# Epoch 119/300
# 1/1 - 0s - loss: 1.0183 - accuracy: 0.7143 - 4ms/epoch - 4ms/step
# Epoch 120/300
# 1/1 - 0s - loss: 1.0068 - accuracy: 0.7143 - 4ms/epoch - 4ms/step
# Epoch 121/300
# 1/1 - 0s - loss: 0.9955 - accuracy: 0.7143 - 3ms/epoch - 3ms/step
# Epoch 122/300
# 1/1 - 0s - loss: 0.9844 - accuracy: 0.7143 - 4ms/epoch - 4ms/step
# Epoch 123/300
# 1/1 - 0s - loss: 0.9734 - accuracy: 0.7143 - 4ms/epoch - 4ms/step
# Epoch 124/300
# 1/1 - 0s - loss: 0.9625 - accuracy: 0.7143 - 4ms/epoch - 4ms/step
# Epoch 125/300
# 1/1 - 0s - loss: 0.9518 - accuracy: 0.7143 - 4ms/epoch - 4ms/step
# Epoch 126/300
# 1/1 - 0s - loss: 0.9412 - accuracy: 0.7143 - 5ms/epoch - 5ms/step
# Epoch 127/300
# 1/1 - 0s - loss: 0.9308 - accuracy: 0.7143 - 4ms/epoch - 4ms/step
# Epoch 128/300
# 1/1 - 0s - loss: 0.9205 - accuracy: 0.7143 - 5ms/epoch - 5ms/step
# Epoch 129/300
# 1/1 - 0s - loss: 0.9104 - accuracy: 0.7143 - 5ms/epoch - 5ms/step
# Epoch 130/300
# 1/1 - 0s - loss: 0.9004 - accuracy: 0.7143 - 5ms/epoch - 5ms/step
# Epoch 131/300
# 1/1 - 0s - loss: 0.8906 - accuracy: 0.7143 - 14ms/epoch - 14ms/step
# Epoch 132/300
# 1/1 - 0s - loss: 0.8809 - accuracy: 0.7143 - 7ms/epoch - 7ms/step
# Epoch 133/300
# 1/1 - 0s - loss: 0.8714 - accuracy: 0.7500 - 7ms/epoch - 7ms/step
# Epoch 134/300
# 1/1 - 0s - loss: 0.8619 - accuracy: 0.7500 - 5ms/epoch - 5ms/step
# Epoch 135/300
# 1/1 - 0s - loss: 0.8527 - accuracy: 0.7500 - 6ms/epoch - 6ms/step
# Epoch 136/300
# 1/1 - 0s - loss: 0.8436 - accuracy: 0.7500 - 5ms/epoch - 5ms/step
# Epoch 137/300
# 1/1 - 0s - loss: 0.8346 - accuracy: 0.7857 - 4ms/epoch - 4ms/step
# Epoch 138/300
# 1/1 - 0s - loss: 0.8257 - accuracy: 0.7857 - 4ms/epoch - 4ms/step
# Epoch 139/300
# 1/1 - 0s - loss: 0.8170 - accuracy: 0.7857 - 5ms/epoch - 5ms/step
# Epoch 140/300
# 1/1 - 0s - loss: 0.8084 - accuracy: 0.7857 - 5ms/epoch - 5ms/step
# Epoch 141/300
# 1/1 - 0s - loss: 0.8000 - accuracy: 0.7857 - 4ms/epoch - 4ms/step
# Epoch 142/300
# 1/1 - 0s - loss: 0.7916 - accuracy: 0.7857 - 4ms/epoch - 4ms/step
# Epoch 143/300
# 1/1 - 0s - loss: 0.7834 - accuracy: 0.7857 - 5ms/epoch - 5ms/step
# Epoch 144/300
# 1/1 - 0s - loss: 0.7754 - accuracy: 0.7857 - 4ms/epoch - 4ms/step
# Epoch 145/300
# 1/1 - 0s - loss: 0.7674 - accuracy: 0.7857 - 5ms/epoch - 5ms/step
# Epoch 146/300
# 1/1 - 0s - loss: 0.7596 - accuracy: 0.7857 - 3ms/epoch - 3ms/step
# Epoch 147/300
# 1/1 - 0s - loss: 0.7519 - accuracy: 0.7857 - 5ms/epoch - 5ms/step
# Epoch 148/300
# 1/1 - 0s - loss: 0.7443 - accuracy: 0.7857 - 3ms/epoch - 3ms/step
# Epoch 149/300
# 1/1 - 0s - loss: 0.7368 - accuracy: 0.7857 - 4ms/epoch - 4ms/step
# Epoch 150/300
# 1/1 - 0s - loss: 0.7295 - accuracy: 0.7857 - 4ms/epoch - 4ms/step
# Epoch 151/300
# 1/1 - 0s - loss: 0.7222 - accuracy: 0.7857 - 5ms/epoch - 5ms/step
# Epoch 152/300
# 1/1 - 0s - loss: 0.7151 - accuracy: 0.8214 - 4ms/epoch - 4ms/step
# Epoch 153/300
# 1/1 - 0s - loss: 0.7080 - accuracy: 0.8214 - 4ms/epoch - 4ms/step
# Epoch 154/300
# 1/1 - 0s - loss: 0.7011 - accuracy: 0.8214 - 5ms/epoch - 5ms/step
# Epoch 155/300
# 1/1 - 0s - loss: 0.6943 - accuracy: 0.8214 - 3ms/epoch - 3ms/step
# Epoch 156/300
# 1/1 - 0s - loss: 0.6876 - accuracy: 0.8214 - 5ms/epoch - 5ms/step
# Epoch 157/300
# 1/1 - 0s - loss: 0.6809 - accuracy: 0.8214 - 3ms/epoch - 3ms/step
# Epoch 158/300
# 1/1 - 0s - loss: 0.6744 - accuracy: 0.8214 - 5ms/epoch - 5ms/step
# Epoch 159/300
# 1/1 - 0s - loss: 0.6680 - accuracy: 0.8214 - 4ms/epoch - 4ms/step
# Epoch 160/300
# 1/1 - 0s - loss: 0.6616 - accuracy: 0.8214 - 5ms/epoch - 5ms/step
# Epoch 161/300
# 1/1 - 0s - loss: 0.6554 - accuracy: 0.8214 - 4ms/epoch - 4ms/step
# Epoch 162/300
# 1/1 - 0s - loss: 0.6492 - accuracy: 0.8214 - 4ms/epoch - 4ms/step
# Epoch 163/300
# 1/1 - 0s - loss: 0.6432 - accuracy: 0.8214 - 4ms/epoch - 4ms/step
# Epoch 164/300
# 1/1 - 0s - loss: 0.6372 - accuracy: 0.8214 - 4ms/epoch - 4ms/step
# Epoch 165/300
# 1/1 - 0s - loss: 0.6313 - accuracy: 0.8214 - 6ms/epoch - 6ms/step
# Epoch 166/300
# 1/1 - 0s - loss: 0.6255 - accuracy: 0.8214 - 4ms/epoch - 4ms/step
# Epoch 167/300
# 1/1 - 0s - loss: 0.6198 - accuracy: 0.8214 - 5ms/epoch - 5ms/step
# Epoch 168/300
# 1/1 - 0s - loss: 0.6141 - accuracy: 0.8214 - 4ms/epoch - 4ms/step
# Epoch 169/300
# 1/1 - 0s - loss: 0.6085 - accuracy: 0.8214 - 5ms/epoch - 5ms/step
# Epoch 170/300
# 1/1 - 0s - loss: 0.6030 - accuracy: 0.8214 - 5ms/epoch - 5ms/step
# Epoch 171/300
# 1/1 - 0s - loss: 0.5976 - accuracy: 0.8214 - 4ms/epoch - 4ms/step
# Epoch 172/300
# 1/1 - 0s - loss: 0.5923 - accuracy: 0.8214 - 4ms/epoch - 4ms/step
# Epoch 173/300
# 1/1 - 0s - loss: 0.5870 - accuracy: 0.8214 - 4ms/epoch - 4ms/step
# Epoch 174/300
# 1/1 - 0s - loss: 0.5818 - accuracy: 0.8571 - 4ms/epoch - 4ms/step
# Epoch 175/300
# 1/1 - 0s - loss: 0.5767 - accuracy: 0.8571 - 4ms/epoch - 4ms/step
# Epoch 176/300
# 1/1 - 0s - loss: 0.5716 - accuracy: 0.8571 - 4ms/epoch - 4ms/step
# Epoch 177/300
# 1/1 - 0s - loss: 0.5666 - accuracy: 0.8571 - 4ms/epoch - 4ms/step
# Epoch 178/300
# 1/1 - 0s - loss: 0.5617 - accuracy: 0.8571 - 5ms/epoch - 5ms/step
# Epoch 179/300
# 1/1 - 0s - loss: 0.5568 - accuracy: 0.8571 - 4ms/epoch - 4ms/step
# Epoch 180/300
# 1/1 - 0s - loss: 0.5520 - accuracy: 0.8571 - 5ms/epoch - 5ms/step
# Epoch 181/300
# 1/1 - 0s - loss: 0.5473 - accuracy: 0.8571 - 4ms/epoch - 4ms/step
# Epoch 182/300
# 1/1 - 0s - loss: 0.5426 - accuracy: 0.8571 - 4ms/epoch - 4ms/step
# Epoch 183/300
# 1/1 - 0s - loss: 0.5380 - accuracy: 0.8571 - 4ms/epoch - 4ms/step
# Epoch 184/300
# 1/1 - 0s - loss: 0.5334 - accuracy: 0.8571 - 4ms/epoch - 4ms/step
# Epoch 185/300
# 1/1 - 0s - loss: 0.5289 - accuracy: 0.8571 - 4ms/epoch - 4ms/step
# Epoch 186/300
# 1/1 - 0s - loss: 0.5245 - accuracy: 0.8571 - 5ms/epoch - 5ms/step
# Epoch 187/300
# 1/1 - 0s - loss: 0.5201 - accuracy: 0.8571 - 4ms/epoch - 4ms/step
# Epoch 188/300
# 1/1 - 0s - loss: 0.5158 - accuracy: 0.8571 - 4ms/epoch - 4ms/step
# Epoch 189/300
# 1/1 - 0s - loss: 0.5115 - accuracy: 0.8571 - 4ms/epoch - 4ms/step
# Epoch 190/300
# 1/1 - 0s - loss: 0.5073 - accuracy: 0.8929 - 5ms/epoch - 5ms/step
# Epoch 191/300
# 1/1 - 0s - loss: 0.5032 - accuracy: 0.8929 - 3ms/epoch - 3ms/step
# Epoch 192/300
# 1/1 - 0s - loss: 0.4991 - accuracy: 0.8929 - 3ms/epoch - 3ms/step
# Epoch 193/300
# 1/1 - 0s - loss: 0.4950 - accuracy: 0.8929 - 4ms/epoch - 4ms/step
# Epoch 194/300
# 1/1 - 0s - loss: 0.4910 - accuracy: 0.8929 - 5ms/epoch - 5ms/step
# Epoch 195/300
# 1/1 - 0s - loss: 0.4871 - accuracy: 0.8929 - 5ms/epoch - 5ms/step
# Epoch 196/300
# 1/1 - 0s - loss: 0.4832 - accuracy: 0.8929 - 4ms/epoch - 4ms/step
# Epoch 197/300
# 1/1 - 0s - loss: 0.4794 - accuracy: 0.8929 - 4ms/epoch - 4ms/step
# Epoch 198/300
# 1/1 - 0s - loss: 0.4756 - accuracy: 0.8929 - 5ms/epoch - 5ms/step
# Epoch 199/300
# 1/1 - 0s - loss: 0.4718 - accuracy: 0.8929 - 7ms/epoch - 7ms/step
# Epoch 200/300
# 1/1 - 0s - loss: 0.4681 - accuracy: 0.8929 - 4ms/epoch - 4ms/step
# Epoch 201/300
# 1/1 - 0s - loss: 0.4645 - accuracy: 0.8929 - 5ms/epoch - 5ms/step
# Epoch 202/300
# 1/1 - 0s - loss: 0.4609 - accuracy: 0.8929 - 5ms/epoch - 5ms/step
# Epoch 203/300
# 1/1 - 0s - loss: 0.4573 - accuracy: 0.8929 - 3ms/epoch - 3ms/step
# Epoch 204/300
# 1/1 - 0s - loss: 0.4538 - accuracy: 0.8929 - 5ms/epoch - 5ms/step
# Epoch 205/300
# 1/1 - 0s - loss: 0.4504 - accuracy: 0.8929 - 4ms/epoch - 4ms/step
# Epoch 206/300
# 1/1 - 0s - loss: 0.4470 - accuracy: 0.8929 - 5ms/epoch - 5ms/step
# Epoch 207/300
# 1/1 - 0s - loss: 0.4436 - accuracy: 0.8929 - 4ms/epoch - 4ms/step
# Epoch 208/300
# 1/1 - 0s - loss: 0.4403 - accuracy: 0.8929 - 5ms/epoch - 5ms/step
# Epoch 209/300
# 1/1 - 0s - loss: 0.4370 - accuracy: 0.8929 - 6ms/epoch - 6ms/step
# Epoch 210/300
# 1/1 - 0s - loss: 0.4338 - accuracy: 0.8929 - 6ms/epoch - 6ms/step
# Epoch 211/300
# 1/1 - 0s - loss: 0.4306 - accuracy: 0.8929 - 4ms/epoch - 4ms/step
# Epoch 212/300
# 1/1 - 0s - loss: 0.4274 - accuracy: 0.8929 - 5ms/epoch - 5ms/step
# Epoch 213/300
# 1/1 - 0s - loss: 0.4243 - accuracy: 0.8929 - 3ms/epoch - 3ms/step
# Epoch 214/300
# 1/1 - 0s - loss: 0.4213 - accuracy: 0.8929 - 4ms/epoch - 4ms/step
# Epoch 215/300
# 1/1 - 0s - loss: 0.4183 - accuracy: 0.8929 - 4ms/epoch - 4ms/step
# Epoch 216/300
# 1/1 - 0s - loss: 0.4153 - accuracy: 0.8929 - 5ms/epoch - 5ms/step
# Epoch 217/300
# 1/1 - 0s - loss: 0.4124 - accuracy: 0.8929 - 5ms/epoch - 5ms/step
# Epoch 218/300
# 1/1 - 0s - loss: 0.4095 - accuracy: 0.8929 - 5ms/epoch - 5ms/step
# Epoch 219/300
# 1/1 - 0s - loss: 0.4066 - accuracy: 0.8929 - 4ms/epoch - 4ms/step
# Epoch 220/300
# 1/1 - 0s - loss: 0.4038 - accuracy: 0.8929 - 3ms/epoch - 3ms/step
# Epoch 221/300
# 1/1 - 0s - loss: 0.4010 - accuracy: 0.8929 - 3ms/epoch - 3ms/step
# Epoch 222/300
# 1/1 - 0s - loss: 0.3983 - accuracy: 0.8929 - 6ms/epoch - 6ms/step
# Epoch 223/300
# 1/1 - 0s - loss: 0.3956 - accuracy: 0.8929 - 3ms/epoch - 3ms/step
# Epoch 224/300
# 1/1 - 0s - loss: 0.3929 - accuracy: 0.8929 - 5ms/epoch - 5ms/step
# Epoch 225/300
# 1/1 - 0s - loss: 0.3903 - accuracy: 0.8929 - 4ms/epoch - 4ms/step
# Epoch 226/300
# 1/1 - 0s - loss: 0.3877 - accuracy: 0.8929 - 4ms/epoch - 4ms/step
# Epoch 227/300
# 1/1 - 0s - loss: 0.3852 - accuracy: 0.8929 - 5ms/epoch - 5ms/step
# Epoch 228/300
# 1/1 - 0s - loss: 0.3827 - accuracy: 0.8929 - 4ms/epoch - 4ms/step
# Epoch 229/300
# 1/1 - 0s - loss: 0.3802 - accuracy: 0.8929 - 4ms/epoch - 4ms/step
# Epoch 230/300
# 1/1 - 0s - loss: 0.3778 - accuracy: 0.8929 - 3ms/epoch - 3ms/step
# Epoch 231/300
# 1/1 - 0s - loss: 0.3754 - accuracy: 0.8929 - 6ms/epoch - 6ms/step
# Epoch 232/300
# 1/1 - 0s - loss: 0.3730 - accuracy: 0.8929 - 4ms/epoch - 4ms/step
# Epoch 233/300
# 1/1 - 0s - loss: 0.3707 - accuracy: 0.8929 - 5ms/epoch - 5ms/step
# Epoch 234/300
# 1/1 - 0s - loss: 0.3684 - accuracy: 0.8929 - 4ms/epoch - 4ms/step
# Epoch 235/300
# 1/1 - 0s - loss: 0.3661 - accuracy: 0.8929 - 4ms/epoch - 4ms/step
# Epoch 236/300
# 1/1 - 0s - loss: 0.3639 - accuracy: 0.8929 - 4ms/epoch - 4ms/step
# Epoch 237/300
# 1/1 - 0s - loss: 0.3617 - accuracy: 0.8929 - 3ms/epoch - 3ms/step
# Epoch 238/300
# 1/1 - 0s - loss: 0.3596 - accuracy: 0.8929 - 5ms/epoch - 5ms/step
# Epoch 239/300
# 1/1 - 0s - loss: 0.3574 - accuracy: 0.8929 - 4ms/epoch - 4ms/step
# Epoch 240/300
# 1/1 - 0s - loss: 0.3553 - accuracy: 0.8929 - 5ms/epoch - 5ms/step
# Epoch 241/300
# 1/1 - 0s - loss: 0.3533 - accuracy: 0.8929 - 3ms/epoch - 3ms/step
# Epoch 242/300
# 1/1 - 0s - loss: 0.3512 - accuracy: 0.8929 - 4ms/epoch - 4ms/step
# Epoch 243/300
# 1/1 - 0s - loss: 0.3492 - accuracy: 0.8929 - 4ms/epoch - 4ms/step
# Epoch 244/300
# 1/1 - 0s - loss: 0.3473 - accuracy: 0.8929 - 5ms/epoch - 5ms/step
# Epoch 245/300
# 1/1 - 0s - loss: 0.3453 - accuracy: 0.8929 - 4ms/epoch - 4ms/step
# Epoch 246/300
# 1/1 - 0s - loss: 0.3434 - accuracy: 0.8929 - 4ms/epoch - 4ms/step
# Epoch 247/300
# 1/1 - 0s - loss: 0.3415 - accuracy: 0.8929 - 5ms/epoch - 5ms/step
# Epoch 248/300
# 1/1 - 0s - loss: 0.3397 - accuracy: 0.8929 - 4ms/epoch - 4ms/step
# Epoch 249/300
# 1/1 - 0s - loss: 0.3379 - accuracy: 0.8929 - 4ms/epoch - 4ms/step
# Epoch 250/300
# 1/1 - 0s - loss: 0.3361 - accuracy: 0.8929 - 4ms/epoch - 4ms/step
# Epoch 251/300
# 1/1 - 0s - loss: 0.3343 - accuracy: 0.8929 - 4ms/epoch - 4ms/step
# Epoch 252/300
# 1/1 - 0s - loss: 0.3326 - accuracy: 0.8929 - 5ms/epoch - 5ms/step
# Epoch 253/300
# 1/1 - 0s - loss: 0.3309 - accuracy: 0.8929 - 5ms/epoch - 5ms/step
# Epoch 254/300
# 1/1 - 0s - loss: 0.3292 - accuracy: 0.8929 - 5ms/epoch - 5ms/step
# Epoch 255/300
# 1/1 - 0s - loss: 0.3275 - accuracy: 0.8929 - 4ms/epoch - 4ms/step
# Epoch 256/300
# 1/1 - 0s - loss: 0.3259 - accuracy: 0.8929 - 4ms/epoch - 4ms/step
# Epoch 257/300
# 1/1 - 0s - loss: 0.3243 - accuracy: 0.8929 - 4ms/epoch - 4ms/step
# Epoch 258/300
# 1/1 - 0s - loss: 0.3227 - accuracy: 0.8929 - 4ms/epoch - 4ms/step
# Epoch 259/300
# 1/1 - 0s - loss: 0.3211 - accuracy: 0.8929 - 4ms/epoch - 4ms/step
# Epoch 260/300
# 1/1 - 0s - loss: 0.3196 - accuracy: 0.8929 - 4ms/epoch - 4ms/step
# Epoch 261/300
# 1/1 - 0s - loss: 0.3181 - accuracy: 0.8929 - 5ms/epoch - 5ms/step
# Epoch 262/300
# 1/1 - 0s - loss: 0.3166 - accuracy: 0.8929 - 4ms/epoch - 4ms/step
# Epoch 263/300
# 1/1 - 0s - loss: 0.3151 - accuracy: 0.8929 - 5ms/epoch - 5ms/step
# Epoch 264/300
# 1/1 - 0s - loss: 0.3137 - accuracy: 0.8929 - 4ms/epoch - 4ms/step
# Epoch 265/300
# 1/1 - 0s - loss: 0.3123 - accuracy: 0.8929 - 4ms/epoch - 4ms/step
# Epoch 266/300
# 1/1 - 0s - loss: 0.3109 - accuracy: 0.8929 - 5ms/epoch - 5ms/step
# Epoch 267/300
# 1/1 - 0s - loss: 0.3095 - accuracy: 0.8929 - 4ms/epoch - 4ms/step
# Epoch 268/300
# 1/1 - 0s - loss: 0.3082 - accuracy: 0.8929 - 5ms/epoch - 5ms/step
# Epoch 269/300
# 1/1 - 0s - loss: 0.3068 - accuracy: 0.8929 - 4ms/epoch - 4ms/step
# Epoch 270/300
# 1/1 - 0s - loss: 0.3055 - accuracy: 0.8929 - 5ms/epoch - 5ms/step
# Epoch 271/300
# 1/1 - 0s - loss: 0.3042 - accuracy: 0.8929 - 4ms/epoch - 4ms/step
# Epoch 272/300
# 1/1 - 0s - loss: 0.3030 - accuracy: 0.8929 - 4ms/epoch - 4ms/step
# Epoch 273/300
# 1/1 - 0s - loss: 0.3017 - accuracy: 0.8929 - 4ms/epoch - 4ms/step
# Epoch 274/300
# 1/1 - 0s - loss: 0.3005 - accuracy: 0.8929 - 4ms/epoch - 4ms/step
# Epoch 275/300
# 1/1 - 0s - loss: 0.2993 - accuracy: 0.8929 - 3ms/epoch - 3ms/step
# Epoch 276/300
# 1/1 - 0s - loss: 0.2981 - accuracy: 0.8929 - 3ms/epoch - 3ms/step
# Epoch 277/300
# 1/1 - 0s - loss: 0.2969 - accuracy: 0.8929 - 6ms/epoch - 6ms/step
# Epoch 278/300
# 1/1 - 0s - loss: 0.2958 - accuracy: 0.8929 - 4ms/epoch - 4ms/step
# Epoch 279/300
# 1/1 - 0s - loss: 0.2946 - accuracy: 0.8929 - 5ms/epoch - 5ms/step
# Epoch 280/300
# 1/1 - 0s - loss: 0.2935 - accuracy: 0.8929 - 3ms/epoch - 3ms/step
# Epoch 281/300
# 1/1 - 0s - loss: 0.2924 - accuracy: 0.8929 - 5ms/epoch - 5ms/step
# Epoch 282/300
# 1/1 - 0s - loss: 0.2913 - accuracy: 0.8929 - 4ms/epoch - 4ms/step
# Epoch 283/300
# 1/1 - 0s - loss: 0.2903 - accuracy: 0.8929 - 4ms/epoch - 4ms/step
# Epoch 284/300
# 1/1 - 0s - loss: 0.2892 - accuracy: 0.8929 - 5ms/epoch - 5ms/step
# Epoch 285/300
# 1/1 - 0s - loss: 0.2882 - accuracy: 0.8929 - 3ms/epoch - 3ms/step
# Epoch 286/300
# 1/1 - 0s - loss: 0.2872 - accuracy: 0.8929 - 5ms/epoch - 5ms/step
# Epoch 287/300
# 1/1 - 0s - loss: 0.2862 - accuracy: 0.8929 - 4ms/epoch - 4ms/step
# Epoch 288/300
# 1/1 - 0s - loss: 0.2852 - accuracy: 0.8929 - 4ms/epoch - 4ms/step
# Epoch 289/300
# 1/1 - 0s - loss: 0.2842 - accuracy: 0.8929 - 5ms/epoch - 5ms/step
# Epoch 290/300
# 1/1 - 0s - loss: 0.2832 - accuracy: 0.8929 - 13ms/epoch - 13ms/step
# Epoch 291/300
# 1/1 - 0s - loss: 0.2823 - accuracy: 0.8929 - 4ms/epoch - 4ms/step
# Epoch 292/300
# 1/1 - 0s - loss: 0.2814 - accuracy: 0.8929 - 6ms/epoch - 6ms/step
# Epoch 293/300
# 1/1 - 0s - loss: 0.2805 - accuracy: 0.8929 - 3ms/epoch - 3ms/step
# Epoch 294/300
# 1/1 - 0s - loss: 0.2796 - accuracy: 0.8929 - 5ms/epoch - 5ms/step
# Epoch 295/300
# 1/1 - 0s - loss: 0.2787 - accuracy: 0.8929 - 4ms/epoch - 4ms/step
# Epoch 296/300
# 1/1 - 0s - loss: 0.2778 - accuracy: 0.8929 - 5ms/epoch - 5ms/step
# Epoch 297/300
# 1/1 - 0s - loss: 0.2769 - accuracy: 0.8929 - 4ms/epoch - 4ms/step
# Epoch 298/300
# 1/1 - 0s - loss: 0.2761 - accuracy: 0.8929 - 5ms/epoch - 5ms/step
# Epoch 299/300
# 1/1 - 0s - loss: 0.2753 - accuracy: 0.8929 - 4ms/epoch - 4ms/step
# Epoch 300/300
# 1/1 - 0s - loss: 0.2744 - accuracy: 0.8929 - 4ms/epoch - 4ms/step

# %%
# 5. 모델 학습과정 시각화
fig, loss_ax = plt.subplots(figsize=(12,6))
loss_ax.plot(hist.history['loss'], 'y', label='train loss')
acc_ax = loss_ax.twinx()
acc_ax.plot(hist.history['accuracy'], 'g', label='train accuracy')
loss_ax.set_xlabel('epochs')
loss_ax.set_ylabel('loss')
acc_ax.set_ylabel('accuracy')
loss_ax.legend(loc='center right')
acc_ax.legend()
plt.show()

# %%
# 모델 사용하기 (경마장에 있는 말이 -> 뛰고)
input_word = input('입력단어 :')
encoded = t.texts_to_sequences([input_word])[0]
input_data = pad_sequences([encoded], # 2차원 데이터 (encoded는 1차원임)
                            maxlen=my_len-1, padding='pre')
print('입력데이터 :', input_data)
result = model.predict(input_data).argmax()
word = t.index_word.get(result, '??')
# word = t.index_word[result]
print('예측된 단어 :', word)
# Out:
# 입력단어 :말이
# 입력데이터 : [[0 0 0 0 1]]
# 1/1 [==============================] - 0s 19ms/step
# 예측된 단어 : 고와야

# %%
t.texts_to_sequences(['없는 단어'])
# Out:
# [[]]

# %% [markdown]
# # 2. 다음 문맥 예측해 보기

# %%
# "경마장에" 이후에 올 단어 ?개 예측 -> 경마장에 있는 말이 뛰고
def sentence_generation(current_word, n):
    print('입력된 단어 :', current_word)
    for i in range(1, n+1):
        encoded = t.texts_to_sequences([current_word])[0]
        input_data = pad_sequences([encoded], maxlen=my_len-1, padding='pre')
        result = model.predict(input_data, verbose=0).argmax()
        word = t.index_word[result]
        current_word = current_word + ' ' + word
#         print("{}번째 생성 문맥({}{}) :".format(i,
#                                           current_word,
#                                          encoded,
#                                          result)) 
    return current_word
sentence_generation('경마장에', 3)
# Out:
# 입력된 단어 : 경마장에
# 1번째 생성 문맥(경마장에 있는[2]) :
# 2번째 생성 문맥(경마장에 있는 말이[2, 3]) :
# 3번째 생성 문맥(경마장에 있는 말이 뛰고[2, 3, 1]) :

# %%
sentence_generation('곱다', 5)
# Out:
# 입력된 단어 : 곱다
# 1번째 생성 문맥(곱다 말이[11]) :
# 2번째 생성 문맥(곱다 말이 고와야[11, 1]) :
# 3번째 생성 문맥(곱다 말이 고와야 오는[11, 1, 9]) :
# 4번째 생성 문맥(곱다 말이 고와야 오는 말이[11, 1, 9, 10]) :
# 5번째 생성 문맥(곱다 말이 고와야 오는 말이 곱다[11, 1, 9, 10, 1]) :
