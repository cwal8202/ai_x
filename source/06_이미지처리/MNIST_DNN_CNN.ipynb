# %%
from IPython.display import display, HTML
display(HTML("""
<style>
div.container{width:86% !important;}
div.cell.code_cell.rendered{width:100%;}
div.CodeMirror {font-family:Consolas; font-size:15pt;}
div.output {font-size:15pt; font-weight:bold;}
div.input {font-family:Consolas; font-size:15pt;}
div.prompt {min-width:70px;}
div#toc-wrapper{padding-top:120px;}
div.text_cell_render ul li{font-size:12pt;padding:5px;}
table.dataframe{font-size:15px;}
</style>
"""))
# Out:
# <style>
# div.container{width:86% !important;}
# div.cell.code_cell.rendered{width:100%;}
# div.CodeMirror {font-family:Consolas; font-size:15pt;}
# div.output {font-size:15pt; font-weight:bold;}
# div.input {font-family:Consolas; font-size:15pt;}
# div.prompt {min-width:70px;}
# div#toc-wrapper{padding-top:120px;}
# div.text_cell_render ul li{font-size:12pt;padding:5px;}
# table.dataframe{font-size:15px;}
# </style>

# %%
import numpy as np
import pandas as pd
from tensorflow.keras.datasets import mnist # mnist 훈련셋과 테스트셋
from tensorflow.keras.utils import to_categorical # 원핫인코딩
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Input, Dropout
from matplotlib import pyplot as plt # 학습과정 loss와 acc 시각화
from sklearn.metrics import confusion_matrix
# quiz에서는 scale 조정, train_test_split 등을 추가

# %%
# 1. 데이터 셋
width = 28; height = 28
(X_train, y_train), (X_test, y_test) = mnist.load_data()
X_train.shape, y_train.shape, X_test.shape, y_test.shape
# Out:
# ((60000, 28, 28), (60000,), (10000, 28, 28), (10000,))

# %%
plt_row = 3
plt_col = 10
# plt.figure(figsize=(plt_col, plt_row))
plt.rcParams['figure.figsize'] = [plt_col, plt_row]
plt.rc("font", family="Malgun Gothic") # window에서 한글 시각화
# plt.rc("font", family="NanumBarunGothic") # 코랩에서 한글 시각화
fig, axes = plt.subplots(plt_row, plt_col)
# axes[0, 0].imshow(X_test[0].reshape(width, height))
# axes[0, 0].axis('off')
# title = "실제:{}".format(y_test[0])
# axes[0, 0].set_title(title)
plt.subplots_adjust(hspace=0.4, wspace=0.3)
for i in range(plt_row*plt_col):
    subax = axes[i//plt_col, i%plt_col] # /// : 몫 연산자, % : 나머지 연산자
    subax.imshow(X_test[i].reshape(width, height))
    subax.axis('off')
    title = "실제:{}".format(y_test[i])
    subax.set_title(title)

# %% [markdown]
# # 1.DNN

# %%
# %%time
# 1. 데이터 생성 및 전처리
width=28; height=28
(X_train, y_train), (X_test, y_test) = mnist.load_data()
X_val = X_train[50000:]
y_val = y_train[50000:]
X_train = X_train[:50000]
y_train = y_train[:50000]
# 독립변수 (28,28) => 784 1차원 -> 실수형변환 -> 스케일조정
X_train = X_train.reshape(-1, width*height).astype('float32')/255.0
X_val = X_val.reshape(-1, width*height).astype('float32')/255.0
X_test = X_test.reshape(-1, width*height).astype('float32')/255.0
# 타겟변수 원핫인코딩
Y_train = to_categorical(y_train)
Y_val = to_categorical(y_val)
Y_test = to_categorical(y_test)

X_train.shape, Y_train.shape, X_val.shape, Y_val.shape, X_test.shape, Y_test.shape

# 2. 모델 구성
model = Sequential([
    Input(shape=(width*height,)),
    Dense(1024, activation='relu'),
    Dropout(0.3),
    Dense(512, activation='relu'),
    Dropout(0.3),
    Dense(256, activation='relu'),
    Dropout(0.2),
    Dense(10, activation='softmax')
])
# model.summary()
# 3. 학습설정
model.compile(loss='categorical_crossentropy', optimizer='adam', metrics=['accuracy'])
# 4. 학습
model.fit(X_train, Y_train,
         epochs=50, 
         validation_data=(X_val, Y_val),
         verbose=1)
# Out:
# Epoch 1/50
# 1563/1563 [==============================] - 19s 12ms/step - loss: 0.2677 - accuracy: 0.9182 - val_loss: 0.1195 - val_accuracy: 0.9642
# Epoch 2/50
# 1563/1563 [==============================] - 18s 11ms/step - loss: 0.1407 - accuracy: 0.9588 - val_loss: 0.0977 - val_accuracy: 0.9716
# Epoch 3/50
# 1563/1563 [==============================] - 18s 12ms/step - loss: 0.1107 - accuracy: 0.9675 - val_loss: 0.0976 - val_accuracy: 0.9709
# Epoch 4/50
# 1563/1563 [==============================] - 18s 12ms/step - loss: 0.0961 - accuracy: 0.9712 - val_loss: 0.0966 - val_accuracy: 0.9720
# Epoch 5/50
# 1563/1563 [==============================] - 18s 12ms/step - loss: 0.0826 - accuracy: 0.9751 - val_loss: 0.0803 - val_accuracy: 0.9778
# Epoch 6/50
# 1563/1563 [==============================] - 18s 12ms/step - loss: 0.0746 - accuracy: 0.9775 - val_loss: 0.0863 - val_accuracy: 0.9754
# Epoch 7/50
# 1563/1563 [==============================] - 19s 12ms/step - loss: 0.0698 - accuracy: 0.9808 - val_loss: 0.1096 - val_accuracy: 0.9712
# Epoch 8/50
# 1563/1563 [==============================] - 18s 12ms/step - loss: 0.0634 - accuracy: 0.9809 - val_loss: 0.0906 - val_accuracy: 0.9776
# Epoch 9/50
# 1563/1563 [==============================] - 18s 12ms/step - loss: 0.0604 - accuracy: 0.9825 - val_loss: 0.0802 - val_accuracy: 0.9809
# Epoch 10/50
# 1563/1563 [==============================] - 18s 12ms/step - loss: 0.0573 - accuracy: 0.9836 - val_loss: 0.0888 - val_accuracy: 0.9793
# Epoch 11/50
# 1563/1563 [==============================] - 18s 12ms/step - loss: 0.0563 - accuracy: 0.9845 - val_loss: 0.0772 - val_accuracy: 0.9802
# Epoch 12/50
# 1563/1563 [==============================] - 19s 12ms/step - loss: 0.0502 - accuracy: 0.9861 - val_loss: 0.1080 - val_accuracy: 0.9781
# Epoch 13/50
# 1563/1563 [==============================] - 19s 12ms/step - loss: 0.0509 - accuracy: 0.9855 - val_loss: 0.0888 - val_accuracy: 0.9797
# Epoch 14/50
# 1563/1563 [==============================] - 19s 12ms/step - loss: 0.0463 - accuracy: 0.9868 - val_loss: 0.0881 - val_accuracy: 0.9800
# Epoch 15/50
# 1563/1563 [==============================] - 19s 12ms/step - loss: 0.0507 - accuracy: 0.9863 - val_loss: 0.1057 - val_accuracy: 0.9784
# Epoch 16/50
# 1563/1563 [==============================] - 19s 12ms/step - loss: 0.0454 - accuracy: 0.9869 - val_loss: 0.1009 - val_accuracy: 0.9818
# Epoch 17/50
# 1563/1563 [==============================] - 19s 12ms/step - loss: 0.0437 - accuracy: 0.9882 - val_loss: 0.0988 - val_accuracy: 0.9816
# Epoch 18/50
# 1563/1563 [==============================] - 19s 12ms/step - loss: 0.0439 - accuracy: 0.9881 - val_loss: 0.1074 - val_accuracy: 0.9816
# Epoch 19/50
# 1563/1563 [==============================] - 19s 12ms/step - loss: 0.0435 - accuracy: 0.9886 - val_loss: 0.1260 - val_accuracy: 0.9773
# Epoch 20/50
# 1563/1563 [==============================] - 19s 12ms/step - loss: 0.0427 - accuracy: 0.9884 - val_loss: 0.1000 - val_accuracy: 0.9822
# Epoch 21/50
# 1563/1563 [==============================] - 19s 12ms/step - loss: 0.0413 - accuracy: 0.9896 - val_loss: 0.1112 - val_accuracy: 0.9819
# Epoch 22/50
# 1563/1563 [==============================] - 19s 12ms/step - loss: 0.0411 - accuracy: 0.9897 - val_loss: 0.1327 - val_accuracy: 0.9799
# Epoch 23/50
# 1563/1563 [==============================] - 19s 12ms/step - loss: 0.0414 - accuracy: 0.9889 - val_loss: 0.1095 - val_accuracy: 0.9808
# Epoch 24/50
# 1563/1563 [==============================] - 19s 12ms/step - loss: 0.0360 - accuracy: 0.9909 - val_loss: 0.1214 - val_accuracy: 0.9808
# Epoch 25/50
# 1563/1563 [==============================] - 19s 12ms/step - loss: 0.0390 - accuracy: 0.9900 - val_loss: 0.1523 - val_accuracy: 0.9806
# Epoch 26/50
# 1563/1563 [==============================] - 19s 12ms/step - loss: 0.0411 - accuracy: 0.9899 - val_loss: 0.1196 - val_accuracy: 0.9819
# Epoch 27/50
# 1563/1563 [==============================] - 19s 12ms/step - loss: 0.0404 - accuracy: 0.9902 - val_loss: 0.1219 - val_accuracy: 0.9806
# Epoch 28/50
# 1563/1563 [==============================] - 19s 12ms/step - loss: 0.0375 - accuracy: 0.9907 - val_loss: 0.1162 - val_accuracy: 0.9826
# Epoch 29/50
# 1563/1563 [==============================] - 19s 12ms/step - loss: 0.0361 - accuracy: 0.9915 - val_loss: 0.1172 - val_accuracy: 0.9827
# Epoch 30/50
# 1563/1563 [==============================] - 19s 12ms/step - loss: 0.0365 - accuracy: 0.9911 - val_loss: 0.1249 - val_accuracy: 0.9817
# Epoch 31/50
# 1563/1563 [==============================] - 19s 12ms/step - loss: 0.0400 - accuracy: 0.9913 - val_loss: 0.1073 - val_accuracy: 0.9822
# Epoch 32/50
# 1563/1563 [==============================] - 19s 12ms/step - loss: 0.0341 - accuracy: 0.9923 - val_loss: 0.1245 - val_accuracy: 0.9813
# Epoch 33/50
# 1563/1563 [==============================] - 21s 13ms/step - loss: 0.0315 - accuracy: 0.9925 - val_loss: 0.1271 - val_accuracy: 0.9831
# Epoch 34/50
# 1563/1563 [==============================] - 21s 14ms/step - loss: 0.0405 - accuracy: 0.9911 - val_loss: 0.1383 - val_accuracy: 0.9813
# Epoch 35/50
# 1563/1563 [==============================] - 19s 12ms/step - loss: 0.0405 - accuracy: 0.9910 - val_loss: 0.1594 - val_accuracy: 0.9799
# Epoch 36/50
# 1563/1563 [==============================] - 19s 12ms/step - loss: 0.0351 - accuracy: 0.9919 - val_loss: 0.1340 - val_accuracy: 0.9822
# Epoch 37/50
# 1563/1563 [==============================] - 20s 13ms/step - loss: 0.0357 - accuracy: 0.9919 - val_loss: 0.1117 - val_accuracy: 0.9835
# Epoch 38/50
# 1563/1563 [==============================] - 19s 12ms/step - loss: 0.0354 - accuracy: 0.9918 - val_loss: 0.1585 - val_accuracy: 0.9820
# Epoch 39/50
# 1563/1563 [==============================] - 19s 12ms/step - loss: 0.0352 - accuracy: 0.9921 - val_loss: 0.1667 - val_accuracy: 0.9823
# Epoch 40/50
# 1563/1563 [==============================] - 20s 13ms/step - loss: 0.0332 - accuracy: 0.9929 - val_loss: 0.1967 - val_accuracy: 0.9828
# Epoch 41/50
# 1563/1563 [==============================] - 20s 13ms/step - loss: 0.0371 - accuracy: 0.9920 - val_loss: 0.1612 - val_accuracy: 0.9815
# Epoch 42/50
# 1563/1563 [==============================] - 20s 13ms/step - loss: 0.0378 - accuracy: 0.9923 - val_loss: 0.1470 - val_accuracy: 0.9832
# Epoch 43/50
# 1563/1563 [==============================] - 20s 12ms/step - loss: 0.0328 - accuracy: 0.9931 - val_loss: 0.1706 - val_accuracy: 0.9812
# Epoch 44/50
# 1563/1563 [==============================] - 20s 13ms/step - loss: 0.0305 - accuracy: 0.9930 - val_loss: 0.1518 - val_accuracy: 0.9839
# Epoch 45/50
# 1563/1563 [==============================] - 18s 12ms/step - loss: 0.0319 - accuracy: 0.9923 - val_loss: 0.1866 - val_accuracy: 0.9823
# Epoch 46/50
# 1563/1563 [==============================] - 19s 12ms/step - loss: 0.0289 - accuracy: 0.9940 - val_loss: 0.1688 - val_accuracy: 0.9828
# Epoch 47/50
# 1563/1563 [==============================] - 18s 12ms/step - loss: 0.0286 - accuracy: 0.9941 - val_loss: 0.1788 - val_accuracy: 0.9834
# Epoch 48/50
# 1563/1563 [==============================] - 20s 13ms/step - loss: 0.0399 - accuracy: 0.9930 - val_loss: 0.1596 - val_accuracy: 0.9823
# Epoch 49/50
# 1563/1563 [==============================] - 20s 13ms/step - loss: 0.0361 - accuracy: 0.9931 - val_loss: 0.1499 - val_accuracy: 0.9833
# Epoch 50/50
# 1563/1563 [==============================] - 20s 13ms/step - loss: 0.0331 - accuracy: 0.9931 - val_loss: 0.1671 - val_accuracy: 0.9835
# CPU times: total: 1h 9min 37s
# Wall time: 15min 51s

# %%
model.save('mnist_dnn.h5')

# %%
model.evaluate(X_test, Y_test)
# Out:
# 313/313 [==============================] - 1s 4ms/step - loss: 0.1577 - accuracy: 0.9841
# [0.1577337235212326, 0.9840999841690063]

# %%
# 혼동행렬
from sklearn.metrics import confusion_matrix
print('실제값 :', y_test)
print('실제값 :', np.argmax(Y_test, axis=1))
yhat = model.predict(X_test).argmax(axis=1)
cmatrix = confusion_matrix(y_test, yhat)
cmatrix
# Out:
# 실제값 : [7 2 1 ... 4 5 6]
# 실제값 : [7 2 1 ... 4 5 6]
# 313/313 [==============================] - 1s 4ms/step
# array([[ 972,    2,    1,    1,    0,    0,    2,    1,    1,    0],
#        [   0, 1132,    1,    0,    0,    0,    0,    0,    2,    0],
#        [   0,    2, 1019,    2,    1,    0,    0,    5,    3,    0],
#        [   0,    0,    4,  993,    0,    4,    0,    2,    2,    5],
#        [   0,    1,    6,    0,  963,    0,    3,    2,    1,    6],
#        [   2,    0,    0,    4,    0,  878,    3,    1,    2,    2],
#        [   2,    3,    0,    1,    1,    5,  944,    0,    2,    0],
#        [   1,    1,   10,    1,    0,    1,    0, 1007,    1,    6],
#        [   2,    1,    3,    4,    4,    2,    0,    4,  953,    1],
#        [   1,    3,    0,    0,   13,    3,    0,    5,    4,  980]],
#       dtype=int64)

# %%
# 실제값과 예측값이 다른 개수(방법1)
cnt = 0
for i, row in enumerate(cmatrix):
    for j, data in enumerate(row):
        if i!=j:
            cnt += data
print('예측이 틀린 갯수 :', cnt)
# Out:
# 예측이 틀린 갯수 : 159

# %%
# 실제값과 예측값이 다른 개수(방법2)
cnt = 0
for y, h in zip(y_test, yhat):
    if y!=h:
        cnt += 1
cnt
# Out:
# 159

# %%
# CNN을 사용하여 예측이 틀린 데이터 출력(yhat 과 y_test가 다른 것들 159개)
plt_row = 16
plt_col = 10
plt.rcParams['figure.figsize'] = [plt_col, plt_row]
plt.rc("font", family="Malgun Gothic") # window에서 한글 시각화
# plt.rc("font", family="NanumBarunGothic") # 코랩에서 한글 시각화
fig, axes = plt.subplots(plt_row, plt_col)
plt.subplots_adjust(hspace=0.4, wspace=0.3)

i=0 # yhat과 y_test의 index => yhat[i], y_test[i]를 비교
cnt = 0 # 이미지 출력횟수
while (i<len(y_test)) & (cnt < plt_row*plt_col):
    if yhat[i] == y_test[i]:
        i += 1
        continue
    subax = axes[cnt//plt_col, cnt%plt_col] # /// : 몫 연산자, % : 나머지 연산자
    subax.imshow(X_test[i].reshape(width, height))
    subax.axis('off')
    title = "y:{}, h:{}".format(y_test[i], yhat[i])
    subax.set_title(title)
    cnt += 1 # 이미지 출력 번호 증가
    i += 1 # index 증가

# %% [markdown]
# # CNN(컨볼루션 레이어 포함) - 교안 31page

# %%
from tensorflow.keras.datasets import mnist
from tensorflow.keras.utils import to_categorical
from tensorflow.keras.models import Sequential, save_model
from tensorflow.keras.layers import Input,Conv2D, MaxPool2D, Flatten, Dropout, Dense
from tensorflow.keras.callbacks import EarlyStopping
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
from sklearn.metrics import confusion_matrix

# %%
# 1. 데이터 생성 및 전처리
width=28; height=28
(X_train, y_train), (X_test, y_test)= mnist.load_data()
X_val = X_train[50000:]
y_val = y_train[50000:]
X_train = X_train[:50000]
y_train = y_train[:50000]
# 독립변수 (28,28) => 784 1차원 -> 실수형변환 -> 스케일조정
X_train = X_train.reshape(-1, width, height).astype('float32')/255.0
X_val = X_val.reshape(-1, width, height).astype('float32')/255.0
X_test = X_test.reshape(-1, width, height).astype('float32')/255.0
# 타겟변수 원핫인코딩
Y_train = to_categorical(y_train)
Y_val = to_categorical(y_val)
Y_test = to_categorical(y_test)

X_train.shape, Y_train.shape, X_val.shape, Y_val.shape, X_test.shape, Y_test.shape
# Out:
# ((50000, 784),
#  (50000, 10),
#  (10000, 784),
#  (10000, 10),
#  (10000, 784),
#  (10000, 10))

# %%
# 2. 모델생성
model = Sequential()
model.add(Conv2D(filters=32, # 필터 갯수
                kernel_size=3, # 필터 사이즈 3*3
                padding='same', # zero-padding을 하면 출력사이즈도 동일
                input_shape=(width, height, 1), # 입력채널 1개, 필터 32개 => 28*28*32 채널 출력
                activation='relu'
                ))
model.add(MaxPool2D(pool_size=(2,2))) # => 14*14*32
model.add(Dropout(0.1))
model.add(Conv2D(64, (3,3), activation='relu')) # => ((14-3+1)*(14-3+1)*32) * 64
model.add(MaxPool2D(pool_size=(2,2))) # => 6*6
model.add(Dropout(0.25))
model.add(Flatten()) # 입력을 1차원으로
model.add(Dense(units=128, activation='relu'))
model.add(Dropout(0.5))
model.add(Dense(units=10, activation='softmax'))
model.summary()
# 320 => (3x3 필터가 weight 9 +1(bias))*32개 필터
# 18,496 (3*3필터가 weight 3*3*32)
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d (Conv2D)             (None, 28, 28, 32)        320
#
#  max_pooling2d (MaxPooling2D  (None, 14, 14, 32)       0
#  )
#
#  dropout (Dropout)           (None, 14, 14, 32)        0
#
#  conv2d_1 (Conv2D)           (None, 12, 12, 64)        18496
#
#  max_pooling2d_1 (MaxPooling  (None, 6, 6, 64)         0
#  2D)
#
#  dropout_1 (Dropout)         (None, 6, 6, 64)          0
#
#  flatten (Flatten)           (None, 2304)              0
#
#  dense (Dense)               (None, 128)               295040
#
#  dropout_2 (Dropout)         (None, 128)               0
#
#  dense_1 (Dense)             (None, 10)                1290
#
# =================================================================
# Total params: 315,146
# Trainable params: 315,146
# Non-trainable params: 0
# _________________________________________________________________

# %%
# %%time
# 3. 학습설정
model.compile(loss='categorical_crossentropy', optimizer='adam', metrics=['accuracy'])
# 4. 학습
earlyStopping = EarlyStopping(patience=20)
hist = model.fit(X_train, Y_train,
         epochs=50, batch_size=32,
         validation_data=(X_val, Y_val),
         callbacks=[earlyStopping])

# %%
# 5. 모델 학습과정 시각화
fig, loss_ax = plt.subplots(figsize=(12,6))
loss_ax.plot(hist.history['loss'], 'y', label='train loss')
loss_ax.plot(hist.history['val_loss'], 'r', label='val loss')
acc_ax = loss_ax.twinx()
acc_ax.plot(hist.history['accuracy'], 'g', label='train accuracy')
acc_ax.plot(hist.history['val_accuracy'], 'b', label='val accuracy')
loss_ax.set_xlabel('epochs')
loss_ax.set_ylabel('loss')
acc_ax.set_ylabel('accuracy')
loss_ax.legend(loc='center right')
acc_ax.legend()
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[4], line 3
#       1 # 5. 모델 학습과정 시각화
#       2 fig, loss_ax = plt.subplots(figsize=(12,6))
# ----> 3 loss_ax.plot(hist.history['loss'], 'y', label='train loss')
#       4 loss_ax.plot(hist.history['val_loss'], 'r', label='val loss')
#       5 acc_ax = loss_ax.twinx()
#
# NameError: name 'hist' is not defined

# %%
model.evaluate(X_test,Y_test)
# Out:
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# Cell In[5], line 1
# ----> 1 model.evaluate(X_test,Y_test)
#
# File ~\anaconda3\envs\ml-dl-nlp\lib\site-packages\keras\utils\traceback_utils.py:70, in filter_traceback.<locals>.error_handler(*args, **kwargs)
#      67     filtered_tb = _process_traceback_frames(e.__traceback__)
#      68     # To get the full stack trace, call:
#      69     # `tf.debugging.disable_traceback_filtering()`
# ---> 70     raise e.with_traceback(filtered_tb) from None
#      71 finally:
#      72     del filtered_tb
#
# File ~\anaconda3\envs\ml-dl-nlp\lib\site-packages\keras\engine\training.py:3618, in Model._assert_compile_was_called(self)
#    3612 def _assert_compile_was_called(self):
#    3613     # Checks whether `compile` has been called. If it has been called,
#    3614     # then the optimizer is set. This is different from whether the
#    3615     # model is compiled
#    3616     # (i.e. whether the model is built and its inputs/outputs are set).
#    3617     if not self._is_compiled:
# -> 3618         raise RuntimeError(
#    3619             "You must compile your model before "
#    3620             "training/testing. "
#    3621             "Use `model.compile(optimizer, loss)`."
#    3622         )
#
# RuntimeError: You must compile your model before training/testing. Use `model.compile(optimizer, loss)`.

# %%
print('실제값 :', y_test)
print('실제값 :', Y_test.argmax(axis=1))
yhat = model.predict(X_test).argmax(axis=1)
print('예측값 :', yhat)

# %%
cmatrix = confusion_matrix(y_test, yhat)
cmatrix

# %%
# 실제값과 예측값이 다른 갯수
cnt = 0
for y, h in zip(y_test, yhat) :
  if y!=h :
    cnt+=1
print('예측이 틀린 갯수 :', cnt)

# %%
# CNN을 사용하여 예측이 틀린 데이터 출력(yhat 과 y_test가 다른 것들 75개)
plt_row = 7
plt_col = 10
plt.rcParams['figure.figsize'] = [plt_col, plt_row]
plt.rc("font", family="NanumBarunGothic") # 코랩에서 한글 시각화
fig, axes = plt.subplots(plt_row, plt_col)
plt.subplots_adjust(hspace=0.4, wspace=0.3)

i=0 # yhat과 y_test의 index => yhat[i], y_test[i]를 비교
cnt = 0 # 이미지 출력횟수
while (i<len(y_test)) & (cnt < plt_row*plt_col):
    if yhat[i] == y_test[i]:
        i += 1
        continue
    subax = axes[cnt//plt_col, cnt%plt_col] # /// : 몫 연산자, % : 나머지 연산자
    subax.imshow(X_test[i].reshape(width, height))
    subax.axis('off')
    title = "y:{}, h:{}".format(y_test[i], yhat[i])
    subax.set_title(title)
    cnt += 1 # 이미지 출력 번호 증가
    i += 1 # index 증가
